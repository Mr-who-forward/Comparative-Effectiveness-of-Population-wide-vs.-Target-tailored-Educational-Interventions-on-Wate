# %% [markdown]
# ********************

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# %% [markdown]
# # 1. Agent学生主体

# %%
import random
import numpy as np
from numpy.polynomial.polynomial import Polynomial
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from mesa import Agent, Model
from mesa.time import RandomActivation
from numpy.random import normal
from mesa.datacollection import DataCollector  # 导入数据收集器，用于记录模型和主体的数据。
import networkx as nx


# 学生主体类
class StudentAgent(Agent):
    def __init__(self, unique_id, model, summer_start, summer_end, winter_start, winter_end, holiday_effects, profile="normal", grade=None, faculty=None, green_education=False,c_d_ratio=(0.5, 0.5)):
        """
        初始化学生主体。
        Args:
            unique_id (int): 学生唯一编号。
            model (Model): 模型对象。
            summer_start (str): 暑假开始日期（YYYY-MM-DD）。
            summer_end (str): 暑假结束日期（YYYY-MM-DD）。
            winter_start (str): 寒假开始日期（YYYY-MM-DD）。
            winter_end (str): 寒假结束日期（YYYY-MM-DD）。
            holiday_effects (dict): 假期效应字典，键为日期字符串（YYYY-MM-DD），值为假期类型。
            profile (str): 学生行为类型。
            grade (str): 学生年级。
            faculty (str): 学生专业。
            green_education (bool): 是否参与绿色教育课程。
        """
        super().__init__(unique_id, model)
        # print(self.current_date)
        self.is_on_campus = True  # 是否在校状态

        # 设置寒暑假信息
        self.summer_start = datetime.strptime(summer_start, "%Y-%m-%d")
        self.summer_end = datetime.strptime(summer_end, "%Y-%m-%d")
        self.winter_start = datetime.strptime(winter_start, "%Y-%m-%d")
        self.winter_end = datetime.strptime(winter_end, "%Y-%m-%d")

        # 假期效应和参数
        self.holiday_effects = holiday_effects

        # 社会学信息
        self.profile = profile
        self.grade = grade
        self.faculty = faculty
        self.green_education = green_education
        self.c, self.d = c_d_ratio

        # 基础用水量
        self.base_consumption = self.calculate_base_consumption()

        # 每天淋浴和洗衣服的概率
        self.shower_probs = [0.60, 0.65, 0.65, 0.63, 0.64, 0.62, 0.70]
        self.laundry_probs = [0.40, 0.40, 0.40, 0.40, 0.45, 0.45, 0.45]

        # 内嵌的暑假和寒假多项式系数
        self._summer_coefficients = [1.29118706e+02, -5.03312290e+00, 3.04662047e-01,
                                     -1.17554861e-02, 1.97107970e-04, -1.08127357e-06]
        self._winter_coefficients = [9.64941223e+01, -3.89556082e+00, -2.82518473e-01,
                                     1.75204478e-02, -1.02462403e-04, -2.31572036e-06]
        self.summer_probability_poly = Polynomial(self._summer_coefficients)
        self.winter_probability_poly = Polynomial(self._winter_coefficients)


    def calculate_behavior_utilities(self, neighbors_behavior):
        """
        根据邻居行为计算行为效用。
        """
        V_env = neighbors_behavior["environmentalist"]
        V_normal = neighbors_behavior["normal"]

        # 根据是否接受绿色教育，获取行为效用的系数【这个系数设置的太小，会使得转变和不转变收到邻居的影响较小，同样a/b/c/d不要求加起来和为1之类的】
        if self.green_education:
            a, b, c, d = 0.7, 0.3, self.c, self.d
        else:
            a, b, c, d = 0.7, 0.3, 0.3, 0.7

        if self.profile == "environmentalist":
            U_env_to_env = a * V_env
            U_env_to_normal = b * V_normal
            return U_env_to_env, U_env_to_normal
        else:  # self.profile == "normal"
            U_normal_to_env = c * V_env
            U_normal_to_normal = d * V_normal
            return U_normal_to_env, U_normal_to_normal

    def calculate_base_consumption(self):
        """定义基础设备的每日用水量（单位：升）。"""
        # 根据 profile 设置基础用水量
        if self.profile == "environmentalist":
            base_usage = {"toilet": 6, "sink": 12}
        else:  # profile == "normal"
            base_usage = {"toilet": 11, "sink": 17}
        
        return sum(base_usage.values())

    def calculate_daily_water_usage(self):
        """计算每日用水量。"""
        if not self.is_on_campus:
            return 0  # 如果不在校，直接返回0

        day_of_week = self.model.current_date.weekday()  # 直接从模型获取当前日期
        daily_consumption = self.base_consumption

        # 根据 profile 设置额外用水量参数
        if self.profile == "environmentalist":
            shower_usage = 60
            laundry_usage = 100
        else:  # profile == "normal"
            shower_usage = 80
            laundry_usage = 110

        # 计算额外用水量
        if random.random() < self.shower_probs[day_of_week]:
            daily_consumption += shower_usage
        if random.random() < self.laundry_probs[day_of_week]:
            daily_consumption += laundry_usage

        # 加入正态分布随机扰动（均值为 daily_consumption，标准差为 5% 的 daily_consumption）
        daily_consumption_with_noise = max(0, normal(daily_consumption, daily_consumption * 0.05))
        return daily_consumption_with_noise

    def update_on_campus_status(self):
        current_date = self.model.current_date  # 使用模型的当前日期
        if self.summer_start <= current_date <= self.summer_end:
            day_count = (current_date - self.summer_start).days
            on_campus_probability = self.summer_probability_poly(day_count) / 100
        elif self.winter_start <= current_date <= self.winter_end:
            day_count = (current_date - self.winter_start).days
            on_campus_probability = self.winter_probability_poly(day_count) / 100
        else:
            if current_date in self.holiday_effects:
                daily_effect = sum(self.holiday_effects[current_date].values())
                on_campus_probability = 0.9 - daily_effect
            else:
                on_campus_probability = np.random.normal(0.9, 0.01)

        on_campus_probability = max(0, min(on_campus_probability, 1))
        self.is_on_campus = np.random.rand() < on_campus_probability


    def get_water(self):
        """执行每日更新并返回每日用水量。"""
        self.update_on_campus_status()
        # print(self.model.current_date, self.is_on_campus)
        daily_usage = self.calculate_daily_water_usage()
        return daily_usage

# %% [markdown]
# # 2. 交互调度器

# %%
class StudentModel(Model):
    def __init__(self, num_agents, start_date, holiday_effects, beta=1.0, normal_env_ratio=(7, 3), num_neighbors=4, c_d_ratio=(0.5, 0.5), interaction_interval=30):
        # 显式调用父类的初始化方法
        super().__init__()
        self.num_agents = num_agents
        self.holiday_effects = holiday_effects
        self.schedule = RandomActivation(self)
        
        # 初始化模拟开始日期
        self.current_date = datetime.strptime(start_date, "%Y-%m-%d")

        # 社会学比例
        self.faculty_total_ratio = {"A": [100, 100, 100, 100], "B": [100, 100, 100, 100], "C": [25, 25, 25, 25], "D": [25, 25, 25, 25]}
        self.course_attendance_ratio = {"A": [13, 30, 24, 13], "B": [4, 7, 6, 3], "C": [4, 7, 6, 3], "D": [1, 2, 1, 1]}  # 1倍比例
        
        # 创建数据收集器
        self.datacollector = DataCollector(
            agent_reporters={
                "WaterUsage": lambda a: a.get_water()  # 调用 get_water 方法并记录其返回值
            }
        )
        self.interaction_groups = []  # 存储分组信息
        # 设置 beta 参数，默认为 1.0
        self.beta = beta
        self.num_neighbors = num_neighbors  # Number of neighbors for each agent
        self.c_d_ratio = c_d_ratio  # Store the c_d_ratio
        self.interaction_interval = interaction_interval
        self.normal_env_ratio = normal_env_ratio  # Store the ratio
        self.create_agents()

                
    def create_agents(self):
        """创建学生主体并加入调度器。"""
        # 打印调试信息，确保 c_d_ratio 被正确传递
        
        for i in range(self.num_agents):
            faculty, grade = self.assign_faculty_and_grade()
            green_education = self.assign_green_education(faculty, grade)
            profile = self.assign_profile()
            summer_start, summer_end = "2023-06-26", "2023-08-31"
            winter_start, winter_end = "2024-01-21", "2024-02-25"
            agent = StudentAgent(
                unique_id=i,
                model=self,
                summer_start=summer_start,
                summer_end=summer_end,
                winter_start=winter_start,
                winter_end=winter_end,
                holiday_effects=self.holiday_effects,
                profile=profile,
                grade=grade,
                faculty=faculty,
                green_education=green_education,
                c_d_ratio=self.c_d_ratio
            )
            self.schedule.add(agent)

    def assign_faculty_and_grade(self):
        """根据比例随机分配专业和年级。"""
        faculty = random.choices(population=list(self.faculty_total_ratio.keys()), weights=[sum(self.faculty_total_ratio[f]) for f in self.faculty_total_ratio])[0]
        grade = random.choices(population=["大一", "大二", "大三", "大四"], weights=self.faculty_total_ratio[faculty])[0]
        return faculty, grade

    def assign_green_education(self, faculty, grade):
        """根据课程比例决定是否参加绿色教育。"""
        grades = ["大一", "大二", "大三", "大四"]
        grade_index = grades.index(grade)
        course_ratio = self.course_attendance_ratio[faculty][grade_index]
        total_students_in_grade = self.faculty_total_ratio[faculty][grade_index]
        return random.random() < (course_ratio / total_students_in_grade)

    def assign_profile(self):
        """根据外部输入的比例分配 Normal 和 Environmentalist。"""
        normal_weight, env_weight = self.normal_env_ratio  # Use the external ratio
        return random.choices(population=["normal", "environmentalist"], weights=[normal_weight, env_weight])[0]
        
    def create_interaction_groups(self):
        """根据小世界网络生成代理的交互组"""
        # 创建小世界网络
        G = nx.watts_strogatz_graph(self.num_agents, self.num_neighbors, 0.2)  # 4个邻居，重连概率为0.2

        # 基于年级、学科、是否参加清洁生产导论课程建立连接
        for node in G.nodes():
            agent = self.agents[node]
            neighbors = list(G.neighbors(node))
            
            # 确保每个邻居的连接是双向的
            for neighbor in neighbors:
                # 确保在邻居的列表中也有反向链接
                if agent.grade == self.agents[neighbor].grade:
                    G[node][neighbor]['weight'] = 2
                elif agent.faculty == self.agents[neighbor].faculty:
                    G[node][neighbor]['weight'] = 1.5
                elif agent.green_education == self.agents[neighbor].green_education:
                    G[node][neighbor]['weight'] = 1.2
                else:
                    G[node][neighbor]['weight'] = 1

        # 确保每个代理的邻居是双向的
        self.interaction_groups = []
        for node in G.nodes():
            neighbors = list(G.neighbors(node))
            group = [(self.agents[node], [self.agents[neighbor] for neighbor in neighbors])]
            self.interaction_groups.append(group)
        
        # 输出调试信息，查看是否是双向连接
        # print(f"Created {len(self.interaction_groups)} interaction groups.")

        # 检查每个代理的邻居是否双向连接
        for node in G.nodes():
            # print(f"Checking neighbors for Node {node}")
            # print(list(G.neighbors(node)))
            neighbors = list(G.neighbors(node))
            for neighbor in neighbors:
                if node not in list(G.neighbors(neighbor)):
                    print(f"Warning: Node {node} and Node {neighbor} are not bidirectional.")
        
    def interact_agents(self):
        """
        处理每组内的交互逻辑。
        """
        # 用来保存所有代理的行为更新决策
        updates = []

        # 对每个组进行交互
        for group in self.interaction_groups:
            for agent, neighbors in group:
                # 统计邻居行为
                neighbors_behavior = {
                    "environmentalist": sum(1 for a in neighbors if a.profile == "environmentalist") / len(neighbors),
                    "normal": sum(1 for a in neighbors if a.profile == "normal") / len(neighbors),
                }

                # 计算行为效用并决定是否更新行为
                if agent.profile == "environmentalist":
                    U_env_to_env, U_env_to_normal = agent.calculate_behavior_utilities(neighbors_behavior)
                    # 在计算效用时乘以 beta
                    U_env_to_env *= self.beta
                    U_env_to_normal *= self.beta
                    P_env_to_env = np.exp(U_env_to_env) / (np.exp(U_env_to_env) + np.exp(U_env_to_normal))
                    updates.append((agent, "environmentalist" if random.random() < P_env_to_env else "normal"))
                else:  # agent.profile == "normal"
                    U_normal_to_env, U_normal_to_normal = agent.calculate_behavior_utilities(neighbors_behavior)
                    # 在计算效用时乘以 beta
                    U_normal_to_env *= self.beta
                    U_normal_to_normal *= self.beta
                    P_normal_to_env = np.exp(U_normal_to_env) / (np.exp(U_normal_to_env) + np.exp(U_normal_to_normal))
                    updates.append((agent, "environmentalist" if random.random() < P_normal_to_env else "normal"))

        # 一轮交互结束后，再统一更新所有代理的状态
        for agent, new_profile in updates:
            agent.profile = new_profile
            # print(f"Agent {agent.unique_id} updated to: {agent.profile}")


    def step(self):
        """运行模型单步。"""
        # 1. 更新日期
        # print(f"Running step for {self.current_date}")
        self.current_date += timedelta(days=1)

        # 2. 每30天进行一次学生交互
        if (self.current_date - datetime.strptime("2023-05-15", "%Y-%m-%d")).days % self.interaction_interval == 0:
            self.create_interaction_groups()  # 创建新的交互组
            # print(f"Running interaction for {self.current_date}")
            self.interact_agents()

        # 2. 更新每个代理的状态
        self.schedule.step()
        

        # 3. 收集每日数据（如每个学生的用水量）
        self.datacollector.collect(self)

    def get_collected_data(self):
        """获取已收集的数据，返回DataFrame格式以便后续分析或绘图。"""
        return self.datacollector.get_agent_vars_dataframe()

# %% [markdown]
# # 3. 校正 Validation

# %% [markdown]
# ## 3.1 num_agents=1000的时候与现实值偏差

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载实景数据
actual_usage_file_path = 'filled_actual_usage.csv'  # 替换为你的实景数据文件路径
actual_usage_data = pd.read_csv(actual_usage_file_path, index_col=None)
actual_usage_data['ds'] = pd.to_datetime(actual_usage_data['ds'])
actual_usage_data = actual_usage_data.set_index('ds')

# 只取实景数据前365天
actual_usage_data = actual_usage_data.iloc[:365]

# 运行模型
model = StudentModel(num_agents=1240, 
                     start_date="2023-05-20", 
                     holiday_effects=holiday_effects, 
                     beta=5.0, 
                     normal_env_ratio=(5, 5), 
                     num_neighbors=10, 
                     c_d_ratio=(0.3, 0.7),
                     interaction_interval=90)

# 运行365天的模拟
for _ in range(365):
    model.step()  # 调用模型的step方法，检查是否需要进行交互
    model.datacollector.collect(model)  # 收集数据

# 获取代理变量数据并进行汇总
water_data = model.datacollector.get_agent_vars_dataframe()

# 按照步骤 (Step) 汇总每个代理的 daily_usage
daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量

# 将 step 转换为实际日期
daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]  # 映射到实际日期
daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'

model_data = daily_usage.to_frame()

# 可能需要调整日期范围，使两者对齐
model_data = model_data.join(actual_usage_data['actual_usage'], how='left')

# 可选：绘制每日用水量趋势图，包含模型数据和实景数据
plt.figure(figsize=(10, 6))

# 绘制模型数据
plt.plot(model_data.index, model_data['WaterUsage'], color='b', lw=2, label='Model Water Usage')

# 绘制实景数据（如果有）
plt.plot(actual_usage_data.index, actual_usage_data['actual_usage'], color='r', lw=2, linestyle='--', label='Actual Water Usage')

# 添加图例和标题
plt.title("Daily Water Usage Over Time (Model vs Actual)", fontsize=16)
plt.xlabel("Days", fontsize=14)
plt.ylabel("Total Water Usage (kWh)", fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# 显示图表
plt.legend()
plt.show()
# Out:
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1240 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-05-09 00:00:00

# %% [markdown]
# ## 3.2 调整num_agents以最小化误差

# %%
from sklearn.metrics import mean_squared_error

def calculate_mse(model_data, actual_data):
    return mean_squared_error(actual_data.dropna(), model_data.dropna())

# %%
# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 搜索范围
num_agents_range = range(1230, 1261, 10)  # 从100到2000，每次递增100

# 用于存储误差
errors = []

for num_agents in num_agents_range:
    # 运行模型
    model = StudentModel(num_agents=num_agents, 
                         start_date="2023-05-19", 
                         holiday_effects=holiday_effects, 
                         beta=5.0, 
                         normal_env_ratio=(5, 5), 
                         num_neighbors=10, 
                         c_d_ratio=(0.3, 0.7),
                         interaction_interval=90)

    # 模拟运行365天
    for _ in range(365):
        model.step()
        model.datacollector.collect(model)

    # 获取模型数据并对齐日期
    water_data = model.datacollector.get_agent_vars_dataframe()
    daily_usage = water_data.groupby("Step")["WaterUsage"].sum() / 1000
    daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]
    daily_usage.index.name = 'ds'
    model_data = daily_usage.to_frame()
    
    # 计算误差（与实际数据对齐）
    model_data = model_data.join(actual_usage_data['actual_usage'], how='left')
    mse = calculate_mse(model_data['WaterUsage'], model_data['actual_usage'])
    errors.append((num_agents, mse))

    print(f"num_agents={num_agents}, MSE={mse}")
# Out:
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1230 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1230 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1230 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1230 interaction groups.
# Running interaction for 2024-05-09 00:00:00
# num_agents=1230, MSE=364.19656032843983
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1240 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-05-09 00:00:00
# num_agents=1240, MSE=364.8359162806481
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1250 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1250 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1250 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1250 interaction groups.
# Running interaction for 2024-05-09 00:00:00
# num_agents=1250, MSE=368.81883205356417
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1260 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1260 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1260 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1260 interaction groups.
# Running interaction for 2024-05-09 00:00:00
# num_agents=1260, MSE=371.5774195644436

# %%
# 找到最优 num_agents
optimal_num_agents, min_error = min(errors, key=lambda x: x[1])
print(f"最优 num_agents={optimal_num_agents}, 最小误差={min_error}")
# Out:
# 最优 num_agents=1230, 最小误差=364.19656032843983

# %%
# 提取 num_agents 和误差
num_agents_list, mse_list = zip(*errors)

# 绘制曲线
plt.figure(figsize=(10, 6))
plt.plot(num_agents_list, mse_list, marker='o', linestyle='-', color='b')
plt.title("Error vs. Number of Agents", fontsize=16)
plt.xlabel("Number of Agents", fontsize=14)
plt.ylabel("Mean Squared Error (MSE)", fontsize=14)
plt.grid(True)
plt.xticks(num_agents_list, rotation=45)
plt.tight_layout()

# 显示图表
plt.show()

# %% [markdown]
# 选择1240

# %% [markdown]
# ## 3.3 保存最模型的最大最小范围

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 运行模型
model = StudentModel(num_agents=1240, 
                     start_date="2023-05-19", 
                     holiday_effects=holiday_effects, 
                     beta=50.0, 
                     normal_env_ratio=(10, 0), 
                     num_neighbors=10, 
                     c_d_ratio=(0.5, 0.5),
                     interaction_interval=90)

# 运行365天的模拟
for _ in range(365):
    model.step()  # 调用模型的step方法，检查是否需要进行交互
    model.datacollector.collect(model)  # 收集数据

# 获取代理变量数据并进行汇总
water_data = model.datacollector.get_agent_vars_dataframe()

# 按照步骤 (Step) 汇总每个代理的 daily_usage
daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
# 将 step 转换为实际日期
daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]  # 映射到实际日期
daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'
# 将结果保存到 CSV 文件
daily_usage.to_csv("baseline_daily_usage_df_max.csv")

# 可选：绘制每日用水量趋势图
plt.figure(figsize=(10, 6))
daily_usage.plot(kind="line", color='b', lw=2)  # 蓝色线条，宽度为2
plt.title("Daily Water Usage Over Time", fontsize=16)
plt.xlabel("Days", fontsize=14)
plt.ylabel("Total Water Usage (kWh)", fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# 显示图表
plt.show()
# Out:
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1240 interaction groups.
# Running interaction for 2023-08-13 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2023-11-11 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-02-09 00:00:00
# Created 1240 interaction groups.
# Running interaction for 2024-05-09 00:00:00

# %% [markdown]
# ## 3.4 确定baseline

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载最大值和最小值文件
max_file_path = 'baseline_daily_usage_df_max.csv'  # 替换为你的最大值文件路径
min_file_path = 'baseline_daily_usage_df_min.csv'  # 替换为你的最小值文件路径

# 读取最大值和最小值数据
max_values = pd.read_csv(max_file_path, index_col=0)
min_values = pd.read_csv(min_file_path, index_col=0)

# 加载真实用水数据
actual_usage_file_path = 'filled_actual_usage.csv'  # 替换为你的真实数据文件路径
actual_usage_data = pd.read_csv(actual_usage_file_path, index_col=None)
actual_usage_data['ds'] = pd.to_datetime(actual_usage_data['ds'])
actual_usage_data = actual_usage_data.set_index('ds')
# 只取实景数据前365天
actual_usage_data = actual_usage_data.iloc[:365]


# 运行模型
model = StudentModel(num_agents=1240, 
                     start_date="2023-05-19", 
                     holiday_effects=holiday_effects, 
                     beta=5.0, 
                     normal_env_ratio=(5, 5), 
                     num_neighbors=10, 
                     c_d_ratio=(0.3, 0.7),
                     interaction_interval=90)

# 运行365天的模拟
for _ in range(365):
    model.step()  # 调用模型的step方法，检查是否需要进行交互
    model.datacollector.collect(model)  # 收集数据

# 获取代理变量数据并进行汇总
water_data = model.datacollector.get_agent_vars_dataframe()

# 按照步骤 (Step) 汇总每个代理的 daily_usage
daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
# 将 step 转换为实际日期
daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]  # 映射到实际日期
daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'
# 获取最大值和最小值
max_daily_usage = max_values['WaterUsage']
min_daily_usage = min_values['WaterUsage']

# 可选：绘制每日用水量趋势图
plt.figure(figsize=(10, 6))

# 绘制阴影区域（最大值和最小值之间的区域）
plt.fill_between(daily_usage.index, min_daily_usage, max_daily_usage, color='gray', alpha=0.3, label='Min-Max Range')

# 绘制正常的每日用水量数据
plt.plot(daily_usage.index, daily_usage, color='b', lw=2, label='Daily Water Usage')
# 绘制真实用水量数据
plt.plot(actual_usage_data.index, actual_usage_data['actual_usage'], color='r', lw=2, linestyle='--', label='Actual Water Usage')

# 添加图例和标题
plt.title("Daily Water Usage Over Time (Model vs Actual with Min-Max Range)", fontsize=16)
plt.xlabel("Days", fontsize=14)
plt.ylabel("Total Water Usage (kWh)", fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# 显示图表
plt.legend()
plt.show()
# Out:
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# Created 1240 interaction groups.
# Created 1240 interaction groups.
# Created 1240 interaction groups.
# Created 1240 interaction groups.

# %%
daily_usage.index
# Out:
# DatetimeIndex(['2023-05-20', '2023-05-21', '2023-05-22', '2023-05-23',
#                '2023-05-24', '2023-05-25', '2023-05-26', '2023-05-27',
#                '2023-05-28', '2023-05-29',
#                ...
#                '2024-05-09', '2024-05-10', '2024-05-11', '2024-05-12',
#                '2024-05-13', '2024-05-14', '2024-05-15', '2024-05-16',
#                '2024-05-17', '2024-05-18'],
#               dtype='datetime64[ns]', name='ds', length=365, freq=None)

# %% [markdown]
# ## 3.5 baseline的基准线变化两图

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载基准数据（baseline），确保日期列为 datetime 类型
baseline_daily_usage_df = pd.read_csv("baseline_daily_usage_df.csv")
baseline_daily_usage_df["date"] = pd.to_datetime(baseline_daily_usage_df["date"])  # 转换为 datetime 类型

# 使用直接的每日用水量数据创建 DataFrame
daily_usage_df = pd.DataFrame({
    "date": pd.date_range(start="2023-05-15", periods=365),  # 模拟日期
    "daily_usage": daily_usage.values  # 每日用水量数据
})

# 计算修改后的数据与基准数据的相对比例
baseline_daily_usage_df["daily_usage"] = baseline_daily_usage_df["daily_usage"] / 1000  # 转换为 m3
daily_usage_df["daily_usage"] = daily_usage_df["daily_usage"] / 1000  # 转换为 m3

# 合并数据以便计算比例
merged_df = pd.merge(baseline_daily_usage_df[['date', 'daily_usage']], 
                     daily_usage_df[['date', 'daily_usage']], 
                     on='date', 
                     suffixes=('_baseline', '_modified'))

# 计算每日用水量的比例
merged_df['usage_ratio'] = merged_df['daily_usage_modified'] / merged_df['daily_usage_baseline']

# 绘制每日用水量变化对比
plt.figure(figsize=(14, 8))

# 绘制基准数据（蓝色）
plt.subplot(2, 1, 1)  # 创建子图，第一张图
plt.plot(baseline_daily_usage_df["date"], baseline_daily_usage_df["daily_usage"], label="基准每日用水量 (m3)", color="blue")
plt.plot(daily_usage_df["date"], daily_usage_df["daily_usage"], label="修改后的每日用水量 (m3)", color="orange")
plt.title("每日用水量变化对比", fontsize=14)
plt.xlabel("日期", fontsize=12)
plt.ylabel("每日用水量 (m3)", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True)

# 绘制修改后的数据与基准数据的比例（第二张图）
plt.subplot(2, 1, 2)  # 创建子图，第二张图
plt.plot(merged_df["date"], merged_df['usage_ratio'], label="修改后的用水量与基准数据的比例", color="green")
plt.title("修改后的用水量与基准数据的相对比例", fontsize=14)
plt.xlabel("日期", fontsize=12)
plt.ylabel("比例", fontsize=12)
plt.grid(True)
plt.tight_layout()  # 自动调整布局
plt.show()

# %%
# model = StudentModel(num_agents=1000, start_date="2023-05-15", holiday_effects=holiday_effects)
for agent in model.schedule.agents:
    print(f"Agent {agent.unique_id}: Profile = {agent.profile}")
# Out:
# Agent 0: Profile = normal
# Agent 1: Profile = environmentalist
# Agent 2: Profile = environmentalist
# Agent 3: Profile = normal
# Agent 4: Profile = normal
# Agent 5: Profile = environmentalist
# Agent 6: Profile = normal
# Agent 7: Profile = normal
# Agent 8: Profile = normal
# Agent 9: Profile = environmentalist
# Agent 10: Profile = normal
# Agent 11: Profile = normal
# Agent 12: Profile = normal
# Agent 13: Profile = environmentalist
# Agent 14: Profile = normal
# Agent 15: Profile = environmentalist
# Agent 16: Profile = environmentalist
# Agent 17: Profile = normal
# Agent 18: Profile = normal
# Agent 19: Profile = environmentalist
# Agent 20: Profile = environmentalist
# Agent 21: Profile = environmentalist
# Agent 22: Profile = normal
# Agent 23: Profile = normal
# Agent 24: Profile = environmentalist
# Agent 25: Profile = environmentalist
# Agent 26: Profile = environmentalist
# Agent 27: Profile = normal
# Agent 28: Profile = normal
# Agent 29: Profile = environmentalist
# Agent 30: Profile = normal
# Agent 31: Profile = normal
# Agent 32: Profile = normal
# Agent 33: Profile = environmentalist
# Agent 34: Profile = normal
# Agent 35: Profile = normal
# Agent 36: Profile = normal
# Agent 37: Profile = normal
# Agent 38: Profile = normal
# Agent 39: Profile = environmentalist
# Agent 40: Profile = normal
# Agent 41: Profile = environmentalist
# Agent 42: Profile = normal
# Agent 43: Profile = normal
# Agent 44: Profile = normal
# Agent 45: Profile = environmentalist
# Agent 46: Profile = normal
# Agent 47: Profile = normal
# Agent 48: Profile = normal
# Agent 49: Profile = normal
# Agent 50: Profile = normal
# Agent 51: Profile = normal
# Agent 52: Profile = normal
# Agent 53: Profile = normal
# Agent 54: Profile = normal
# Agent 55: Profile = environmentalist
# Agent 56: Profile = normal
# Agent 57: Profile = normal
# Agent 58: Profile = environmentalist
# Agent 59: Profile = normal
# Agent 60: Profile = normal
# Agent 61: Profile = normal
# Agent 62: Profile = normal
# Agent 63: Profile = normal
# Agent 64: Profile = environmentalist
# Agent 65: Profile = normal
# Agent 66: Profile = normal
# Agent 67: Profile = environmentalist
# Agent 68: Profile = normal
# Agent 69: Profile = normal
# Agent 70: Profile = normal
# Agent 71: Profile = normal
# Agent 72: Profile = normal
# Agent 73: Profile = normal
# Agent 74: Profile = normal
# Agent 75: Profile = normal
# Agent 76: Profile = environmentalist
# Agent 77: Profile = normal
# Agent 78: Profile = normal
# Agent 79: Profile = environmentalist
# Agent 80: Profile = normal
# Agent 81: Profile = normal
# Agent 82: Profile = normal
# Agent 83: Profile = normal
# Agent 84: Profile = environmentalist
# Agent 85: Profile = normal
# Agent 86: Profile = environmentalist
# Agent 87: Profile = normal
# Agent 88: Profile = normal
# Agent 89: Profile = normal
# Agent 90: Profile = normal
# Agent 91: Profile = normal
# Agent 92: Profile = normal
# Agent 93: Profile = normal
# Agent 94: Profile = normal
# Agent 95: Profile = normal
# Agent 96: Profile = normal
# Agent 97: Profile = normal
# Agent 98: Profile = normal
# Agent 99: Profile = normal
# Agent 100: Profile = normal
# Agent 101: Profile = environmentalist
# Agent 102: Profile = normal
# Agent 103: Profile = normal
# Agent 104: Profile = normal
# Agent 105: Profile = normal
# Agent 106: Profile = environmentalist
# Agent 107: Profile = environmentalist
# Agent 108: Profile = normal
# Agent 109: Profile = normal
# Agent 110: Profile = environmentalist
# Agent 111: Profile = normal
# Agent 112: Profile = normal
# Agent 113: Profile = normal
# Agent 114: Profile = environmentalist
# Agent 115: Profile = normal
# Agent 116: Profile = environmentalist
# Agent 117: Profile = normal
# Agent 118: Profile = normal
# Agent 119: Profile = normal
# Agent 120: Profile = environmentalist
# Agent 121: Profile = environmentalist
# Agent 122: Profile = normal
# Agent 123: Profile = environmentalist
# Agent 124: Profile = normal
# Agent 125: Profile = normal
# Agent 126: Profile = normal
# Agent 127: Profile = normal
# Agent 128: Profile = environmentalist
# Agent 129: Profile = environmentalist
# Agent 130: Profile = normal
# Agent 131: Profile = normal
# Agent 132: Profile = normal
# Agent 133: Profile = normal
# Agent 134: Profile = normal
# Agent 135: Profile = normal
# Agent 136: Profile = normal
# Agent 137: Profile = normal
# Agent 138: Profile = normal
# Agent 139: Profile = normal
# Agent 140: Profile = environmentalist
# Agent 141: Profile = normal
# Agent 142: Profile = normal
# Agent 143: Profile = normal
# Agent 144: Profile = normal
# Agent 145: Profile = normal
# Agent 146: Profile = normal
# Agent 147: Profile = normal
# Agent 148: Profile = normal
# Agent 149: Profile = environmentalist
# Agent 150: Profile = normal
# Agent 151: Profile = normal
# Agent 152: Profile = normal
# Agent 153: Profile = environmentalist
# Agent 154: Profile = normal
# Agent 155: Profile = normal
# Agent 156: Profile = normal
# Agent 157: Profile = normal
# Agent 158: Profile = normal
# Agent 159: Profile = normal
# Agent 160: Profile = environmentalist
# Agent 161: Profile = normal
# Agent 162: Profile = normal
# Agent 163: Profile = normal
# Agent 164: Profile = normal
# Agent 165: Profile = normal
# Agent 166: Profile = normal
# Agent 167: Profile = normal
# Agent 168: Profile = normal
# Agent 169: Profile = normal
# Agent 170: Profile = environmentalist
# Agent 171: Profile = normal
# Agent 172: Profile = environmentalist
# Agent 173: Profile = environmentalist
# Agent 174: Profile = normal
# Agent 175: Profile = normal
# Agent 176: Profile = environmentalist
# Agent 177: Profile = normal
# Agent 178: Profile = environmentalist
# Agent 179: Profile = normal
# Agent 180: Profile = normal
# Agent 181: Profile = environmentalist
# Agent 182: Profile = normal
# Agent 183: Profile = normal
# Agent 184: Profile = normal
# Agent 185: Profile = environmentalist
# Agent 186: Profile = normal
# Agent 187: Profile = environmentalist
# Agent 188: Profile = environmentalist
# Agent 189: Profile = environmentalist
# Agent 190: Profile = environmentalist
# Agent 191: Profile = environmentalist
# Agent 192: Profile = normal
# Agent 193: Profile = normal
# Agent 194: Profile = environmentalist
# Agent 195: Profile = environmentalist
# Agent 196: Profile = normal
# Agent 197: Profile = normal
# Agent 198: Profile = normal
# Agent 199: Profile = normal
# Agent 200: Profile = normal
# Agent 201: Profile = normal
# Agent 202: Profile = normal
# Agent 203: Profile = normal
# Agent 204: Profile = normal
# Agent 205: Profile = normal
# Agent 206: Profile = normal
# Agent 207: Profile = normal
# Agent 208: Profile = normal
# Agent 209: Profile = environmentalist
# Agent 210: Profile = environmentalist
# Agent 211: Profile = environmentalist
# Agent 212: Profile = normal
# Agent 213: Profile = normal
# Agent 214: Profile = environmentalist
# Agent 215: Profile = normal
# Agent 216: Profile = normal
# Agent 217: Profile = normal
# Agent 218: Profile = normal
# Agent 219: Profile = environmentalist
# Agent 220: Profile = normal
# Agent 221: Profile = environmentalist
# Agent 222: Profile = normal
# Agent 223: Profile = normal
# Agent 224: Profile = environmentalist
# Agent 225: Profile = normal
# Agent 226: Profile = normal
# Agent 227: Profile = normal
# Agent 228: Profile = normal
# Agent 229: Profile = normal
# Agent 230: Profile = normal
# Agent 231: Profile = normal
# Agent 232: Profile = normal
# Agent 233: Profile = normal
# Agent 234: Profile = environmentalist
# Agent 235: Profile = environmentalist
# Agent 236: Profile = environmentalist
# Agent 237: Profile = normal
# Agent 238: Profile = normal
# Agent 239: Profile = normal
# Agent 240: Profile = environmentalist
# Agent 241: Profile = normal
# Agent 242: Profile = normal
# Agent 243: Profile = environmentalist
# Agent 244: Profile = normal
# Agent 245: Profile = normal
# Agent 246: Profile = normal
# Agent 247: Profile = normal
# Agent 248: Profile = normal
# Agent 249: Profile = normal
# Agent 250: Profile = environmentalist
# Agent 251: Profile = normal
# Agent 252: Profile = normal
# Agent 253: Profile = environmentalist
# Agent 254: Profile = normal
# Agent 255: Profile = environmentalist
# Agent 256: Profile = normal
# Agent 257: Profile = environmentalist
# Agent 258: Profile = normal
# Agent 259: Profile = environmentalist
# Agent 260: Profile = normal
# Agent 261: Profile = normal
# Agent 262: Profile = environmentalist
# Agent 263: Profile = environmentalist
# Agent 264: Profile = normal
# Agent 265: Profile = environmentalist
# Agent 266: Profile = normal
# Agent 267: Profile = environmentalist
# Agent 268: Profile = normal
# Agent 269: Profile = normal
# Agent 270: Profile = normal
# Agent 271: Profile = normal
# Agent 272: Profile = normal
# Agent 273: Profile = normal
# Agent 274: Profile = normal
# Agent 275: Profile = normal
# Agent 276: Profile = normal
# Agent 277: Profile = environmentalist
# Agent 278: Profile = normal
# Agent 279: Profile = environmentalist
# Agent 280: Profile = normal
# Agent 281: Profile = normal
# Agent 282: Profile = normal
# Agent 283: Profile = environmentalist
# Agent 284: Profile = normal
# Agent 285: Profile = normal
# Agent 286: Profile = environmentalist
# Agent 287: Profile = normal
# Agent 288: Profile = normal
# Agent 289: Profile = normal
# Agent 290: Profile = normal
# Agent 291: Profile = normal
# Agent 292: Profile = environmentalist
# Agent 293: Profile = normal
# Agent 294: Profile = environmentalist
# Agent 295: Profile = normal
# Agent 296: Profile = normal
# Agent 297: Profile = environmentalist
# Agent 298: Profile = normal
# Agent 299: Profile = normal
# Agent 300: Profile = normal
# Agent 301: Profile = normal
# Agent 302: Profile = environmentalist
# Agent 303: Profile = normal
# Agent 304: Profile = normal
# Agent 305: Profile = normal
# Agent 306: Profile = environmentalist
# Agent 307: Profile = environmentalist
# Agent 308: Profile = normal
# Agent 309: Profile = normal
# Agent 310: Profile = normal
# Agent 311: Profile = environmentalist
# Agent 312: Profile = environmentalist
# Agent 313: Profile = environmentalist
# Agent 314: Profile = normal
# Agent 315: Profile = normal
# Agent 316: Profile = normal
# Agent 317: Profile = normal
# Agent 318: Profile = normal
# Agent 319: Profile = normal
# Agent 320: Profile = normal
# Agent 321: Profile = normal
# Agent 322: Profile = normal
# Agent 323: Profile = normal
# Agent 324: Profile = normal
# Agent 325: Profile = normal
# Agent 326: Profile = normal
# Agent 327: Profile = normal
# Agent 328: Profile = normal
# Agent 329: Profile = environmentalist
# Agent 330: Profile = normal
# Agent 331: Profile = normal
# Agent 332: Profile = normal
# Agent 333: Profile = environmentalist
# Agent 334: Profile = environmentalist
# Agent 335: Profile = normal
# Agent 336: Profile = normal
# Agent 337: Profile = environmentalist
# Agent 338: Profile = normal
# Agent 339: Profile = normal
# Agent 340: Profile = environmentalist
# Agent 341: Profile = environmentalist
# Agent 342: Profile = normal
# Agent 343: Profile = normal
# Agent 344: Profile = normal
# Agent 345: Profile = environmentalist
# Agent 346: Profile = normal
# Agent 347: Profile = normal
# Agent 348: Profile = normal
# Agent 349: Profile = environmentalist
# Agent 350: Profile = environmentalist
# Agent 351: Profile = normal
# Agent 352: Profile = environmentalist
# Agent 353: Profile = normal
# Agent 354: Profile = normal
# Agent 355: Profile = environmentalist
# Agent 356: Profile = normal
# Agent 357: Profile = normal
# Agent 358: Profile = normal
# Agent 359: Profile = environmentalist
# Agent 360: Profile = normal
# Agent 361: Profile = normal
# Agent 362: Profile = environmentalist
# Agent 363: Profile = normal
# Agent 364: Profile = environmentalist
# Agent 365: Profile = normal
# Agent 366: Profile = normal
# Agent 367: Profile = normal
# Agent 368: Profile = normal
# Agent 369: Profile = normal
# Agent 370: Profile = normal
# Agent 371: Profile = normal
# Agent 372: Profile = normal
# Agent 373: Profile = normal
# Agent 374: Profile = normal
# Agent 375: Profile = normal
# Agent 376: Profile = environmentalist
# Agent 377: Profile = environmentalist
# Agent 378: Profile = environmentalist
# Agent 379: Profile = normal
# Agent 380: Profile = normal
# Agent 381: Profile = normal
# Agent 382: Profile = normal
# Agent 383: Profile = normal
# Agent 384: Profile = normal
# Agent 385: Profile = environmentalist
# Agent 386: Profile = normal
# Agent 387: Profile = environmentalist
# Agent 388: Profile = environmentalist
# Agent 389: Profile = normal
# Agent 390: Profile = normal
# Agent 391: Profile = environmentalist
# Agent 392: Profile = normal
# Agent 393: Profile = environmentalist
# Agent 394: Profile = normal
# Agent 395: Profile = normal
# Agent 396: Profile = normal
# Agent 397: Profile = environmentalist
# Agent 398: Profile = environmentalist
# Agent 399: Profile = normal
# Agent 400: Profile = environmentalist
# Agent 401: Profile = normal
# Agent 402: Profile = environmentalist
# Agent 403: Profile = normal
# Agent 404: Profile = environmentalist
# Agent 405: Profile = normal
# Agent 406: Profile = normal
# Agent 407: Profile = environmentalist
# Agent 408: Profile = normal
# Agent 409: Profile = normal
# Agent 410: Profile = environmentalist
# Agent 411: Profile = normal
# Agent 412: Profile = normal
# Agent 413: Profile = normal
# Agent 414: Profile = environmentalist
# Agent 415: Profile = normal
# Agent 416: Profile = normal
# Agent 417: Profile = normal
# Agent 418: Profile = normal
# Agent 419: Profile = normal
# Agent 420: Profile = environmentalist
# Agent 421: Profile = normal
# Agent 422: Profile = normal
# Agent 423: Profile = normal
# Agent 424: Profile = normal
# Agent 425: Profile = environmentalist
# Agent 426: Profile = normal
# Agent 427: Profile = normal
# Agent 428: Profile = normal
# Agent 429: Profile = normal
# Agent 430: Profile = normal
# Agent 431: Profile = normal
# Agent 432: Profile = environmentalist
# Agent 433: Profile = normal
# Agent 434: Profile = normal
# Agent 435: Profile = normal
# Agent 436: Profile = normal
# Agent 437: Profile = normal
# Agent 438: Profile = normal
# Agent 439: Profile = normal
# Agent 440: Profile = environmentalist
# Agent 441: Profile = normal
# Agent 442: Profile = normal
# Agent 443: Profile = normal
# Agent 444: Profile = normal
# Agent 445: Profile = normal
# Agent 446: Profile = normal
# Agent 447: Profile = environmentalist
# Agent 448: Profile = environmentalist
# Agent 449: Profile = environmentalist
# Agent 450: Profile = environmentalist
# Agent 451: Profile = environmentalist
# Agent 452: Profile = environmentalist
# Agent 453: Profile = normal
# Agent 454: Profile = environmentalist
# Agent 455: Profile = normal
# Agent 456: Profile = normal
# Agent 457: Profile = normal
# Agent 458: Profile = normal
# Agent 459: Profile = normal
# Agent 460: Profile = normal
# Agent 461: Profile = environmentalist
# Agent 462: Profile = normal
# Agent 463: Profile = environmentalist
# Agent 464: Profile = normal
# Agent 465: Profile = environmentalist
# Agent 466: Profile = normal
# Agent 467: Profile = environmentalist
# Agent 468: Profile = normal
# Agent 469: Profile = normal
# Agent 470: Profile = environmentalist
# Agent 471: Profile = environmentalist
# Agent 472: Profile = environmentalist
# Agent 473: Profile = normal
# Agent 474: Profile = normal
# Agent 475: Profile = normal
# Agent 476: Profile = environmentalist
# Agent 477: Profile = normal
# Agent 478: Profile = normal
# Agent 479: Profile = normal
# Agent 480: Profile = normal
# Agent 481: Profile = normal
# Agent 482: Profile = environmentalist
# Agent 483: Profile = normal
# Agent 484: Profile = environmentalist
# Agent 485: Profile = normal
# Agent 486: Profile = environmentalist
# Agent 487: Profile = normal
# Agent 488: Profile = environmentalist
# Agent 489: Profile = normal
# Agent 490: Profile = normal
# Agent 491: Profile = normal
# Agent 492: Profile = normal
# Agent 493: Profile = environmentalist
# Agent 494: Profile = environmentalist
# Agent 495: Profile = normal
# Agent 496: Profile = normal
# Agent 497: Profile = normal
# Agent 498: Profile = normal
# Agent 499: Profile = environmentalist
# Agent 500: Profile = normal
# Agent 501: Profile = normal
# Agent 502: Profile = normal
# Agent 503: Profile = normal
# Agent 504: Profile = normal
# Agent 505: Profile = environmentalist
# Agent 506: Profile = environmentalist
# Agent 507: Profile = normal
# Agent 508: Profile = normal
# Agent 509: Profile = normal
# Agent 510: Profile = normal
# Agent 511: Profile = environmentalist
# Agent 512: Profile = environmentalist
# Agent 513: Profile = normal
# Agent 514: Profile = normal
# Agent 515: Profile = environmentalist
# Agent 516: Profile = normal
# Agent 517: Profile = environmentalist
# Agent 518: Profile = normal
# Agent 519: Profile = normal
# Agent 520: Profile = normal
# Agent 521: Profile = normal
# Agent 522: Profile = normal
# Agent 523: Profile = normal
# Agent 524: Profile = environmentalist
# Agent 525: Profile = environmentalist
# Agent 526: Profile = environmentalist
# Agent 527: Profile = normal
# Agent 528: Profile = normal
# Agent 529: Profile = normal
# Agent 530: Profile = normal
# Agent 531: Profile = normal
# Agent 532: Profile = environmentalist
# Agent 533: Profile = environmentalist
# Agent 534: Profile = environmentalist
# Agent 535: Profile = normal
# Agent 536: Profile = normal
# Agent 537: Profile = environmentalist
# Agent 538: Profile = normal
# Agent 539: Profile = normal
# Agent 540: Profile = environmentalist
# Agent 541: Profile = normal
# Agent 542: Profile = normal
# Agent 543: Profile = environmentalist
# Agent 544: Profile = normal
# Agent 545: Profile = normal
# Agent 546: Profile = normal
# Agent 547: Profile = normal
# Agent 548: Profile = normal
# Agent 549: Profile = normal
# Agent 550: Profile = normal
# Agent 551: Profile = normal
# Agent 552: Profile = normal
# Agent 553: Profile = environmentalist
# Agent 554: Profile = environmentalist
# Agent 555: Profile = normal
# Agent 556: Profile = normal
# Agent 557: Profile = normal
# Agent 558: Profile = normal
# Agent 559: Profile = normal
# Agent 560: Profile = normal
# Agent 561: Profile = normal
# Agent 562: Profile = normal
# Agent 563: Profile = environmentalist
# Agent 564: Profile = normal
# Agent 565: Profile = normal
# Agent 566: Profile = normal
# Agent 567: Profile = normal
# Agent 568: Profile = normal
# Agent 569: Profile = normal
# Agent 570: Profile = environmentalist
# Agent 571: Profile = environmentalist
# Agent 572: Profile = normal
# Agent 573: Profile = normal
# Agent 574: Profile = normal
# Agent 575: Profile = environmentalist
# Agent 576: Profile = environmentalist
# Agent 577: Profile = normal
# Agent 578: Profile = normal
# Agent 579: Profile = normal
# Agent 580: Profile = normal
# Agent 581: Profile = normal
# Agent 582: Profile = normal
# Agent 583: Profile = normal
# Agent 584: Profile = normal
# Agent 585: Profile = normal
# Agent 586: Profile = normal
# Agent 587: Profile = normal
# Agent 588: Profile = environmentalist
# Agent 589: Profile = normal
# Agent 590: Profile = normal
# Agent 591: Profile = environmentalist
# Agent 592: Profile = normal
# Agent 593: Profile = environmentalist
# Agent 594: Profile = normal
# Agent 595: Profile = normal
# Agent 596: Profile = environmentalist
# Agent 597: Profile = environmentalist
# Agent 598: Profile = environmentalist
# Agent 599: Profile = normal
# Agent 600: Profile = normal
# Agent 601: Profile = normal
# Agent 602: Profile = normal
# Agent 603: Profile = normal
# Agent 604: Profile = normal
# Agent 605: Profile = environmentalist
# Agent 606: Profile = environmentalist
# Agent 607: Profile = normal
# Agent 608: Profile = normal
# Agent 609: Profile = environmentalist
# Agent 610: Profile = normal
# Agent 611: Profile = normal
# Agent 612: Profile = normal
# Agent 613: Profile = normal
# Agent 614: Profile = normal
# Agent 615: Profile = normal
# Agent 616: Profile = normal
# Agent 617: Profile = environmentalist
# Agent 618: Profile = normal
# Agent 619: Profile = normal
# Agent 620: Profile = environmentalist
# Agent 621: Profile = normal
# Agent 622: Profile = normal
# Agent 623: Profile = normal
# Agent 624: Profile = environmentalist
# Agent 625: Profile = normal
# Agent 626: Profile = normal
# Agent 627: Profile = normal
# Agent 628: Profile = normal
# Agent 629: Profile = normal
# Agent 630: Profile = normal
# Agent 631: Profile = normal
# Agent 632: Profile = normal
# Agent 633: Profile = normal
# Agent 634: Profile = normal
# Agent 635: Profile = normal
# Agent 636: Profile = environmentalist
# Agent 637: Profile = normal
# Agent 638: Profile = normal
# Agent 639: Profile = environmentalist
# Agent 640: Profile = normal
# Agent 641: Profile = environmentalist
# Agent 642: Profile = normal
# Agent 643: Profile = normal
# Agent 644: Profile = normal
# Agent 645: Profile = environmentalist
# Agent 646: Profile = environmentalist
# Agent 647: Profile = normal
# Agent 648: Profile = environmentalist
# Agent 649: Profile = environmentalist
# Agent 650: Profile = normal
# Agent 651: Profile = normal
# Agent 652: Profile = normal
# Agent 653: Profile = normal
# Agent 654: Profile = normal
# Agent 655: Profile = normal
# Agent 656: Profile = environmentalist
# Agent 657: Profile = environmentalist
# Agent 658: Profile = environmentalist
# Agent 659: Profile = normal
# Agent 660: Profile = normal
# Agent 661: Profile = normal
# Agent 662: Profile = normal
# Agent 663: Profile = normal
# Agent 664: Profile = environmentalist
# Agent 665: Profile = normal
# Agent 666: Profile = normal
# Agent 667: Profile = environmentalist
# Agent 668: Profile = environmentalist
# Agent 669: Profile = normal
# Agent 670: Profile = environmentalist
# Agent 671: Profile = normal
# Agent 672: Profile = normal
# Agent 673: Profile = normal
# Agent 674: Profile = normal
# Agent 675: Profile = normal
# Agent 676: Profile = normal
# Agent 677: Profile = normal
# Agent 678: Profile = normal
# Agent 679: Profile = normal
# Agent 680: Profile = normal
# Agent 681: Profile = environmentalist
# Agent 682: Profile = normal
# Agent 683: Profile = normal
# Agent 684: Profile = environmentalist
# Agent 685: Profile = environmentalist
# Agent 686: Profile = normal
# Agent 687: Profile = environmentalist
# Agent 688: Profile = environmentalist
# Agent 689: Profile = normal
# Agent 690: Profile = normal
# Agent 691: Profile = normal
# Agent 692: Profile = normal
# Agent 693: Profile = environmentalist
# Agent 694: Profile = normal
# Agent 695: Profile = normal
# Agent 696: Profile = environmentalist
# Agent 697: Profile = environmentalist
# Agent 698: Profile = normal
# Agent 699: Profile = normal
# Agent 700: Profile = normal
# Agent 701: Profile = normal
# Agent 702: Profile = environmentalist
# Agent 703: Profile = environmentalist
# Agent 704: Profile = environmentalist
# Agent 705: Profile = normal
# Agent 706: Profile = normal
# Agent 707: Profile = normal
# Agent 708: Profile = normal
# Agent 709: Profile = normal
# Agent 710: Profile = normal
# Agent 711: Profile = environmentalist
# Agent 712: Profile = normal
# Agent 713: Profile = normal
# Agent 714: Profile = environmentalist
# Agent 715: Profile = normal
# Agent 716: Profile = normal
# Agent 717: Profile = environmentalist
# Agent 718: Profile = normal
# Agent 719: Profile = normal
# Agent 720: Profile = normal
# Agent 721: Profile = normal
# Agent 722: Profile = environmentalist
# Agent 723: Profile = environmentalist
# Agent 724: Profile = environmentalist
# Agent 725: Profile = normal
# Agent 726: Profile = normal
# Agent 727: Profile = environmentalist
# Agent 728: Profile = environmentalist
# Agent 729: Profile = environmentalist
# Agent 730: Profile = normal
# Agent 731: Profile = environmentalist
# Agent 732: Profile = environmentalist
# Agent 733: Profile = normal
# Agent 734: Profile = normal
# Agent 735: Profile = normal
# Agent 736: Profile = normal
# Agent 737: Profile = environmentalist
# Agent 738: Profile = environmentalist
# Agent 739: Profile = normal
# Agent 740: Profile = normal
# Agent 741: Profile = normal
# Agent 742: Profile = normal
# Agent 743: Profile = environmentalist
# Agent 744: Profile = normal
# Agent 745: Profile = normal
# Agent 746: Profile = normal
# Agent 747: Profile = environmentalist
# Agent 748: Profile = normal
# Agent 749: Profile = normal
# Agent 750: Profile = normal
# Agent 751: Profile = environmentalist
# Agent 752: Profile = normal
# Agent 753: Profile = normal
# Agent 754: Profile = normal
# Agent 755: Profile = normal
# Agent 756: Profile = normal
# Agent 757: Profile = environmentalist
# Agent 758: Profile = environmentalist
# Agent 759: Profile = normal
# Agent 760: Profile = environmentalist
# Agent 761: Profile = environmentalist
# Agent 762: Profile = environmentalist
# Agent 763: Profile = normal
# Agent 764: Profile = environmentalist
# Agent 765: Profile = normal
# Agent 766: Profile = normal
# Agent 767: Profile = normal
# Agent 768: Profile = environmentalist
# Agent 769: Profile = environmentalist
# Agent 770: Profile = normal
# Agent 771: Profile = normal
# Agent 772: Profile = normal
# Agent 773: Profile = normal
# Agent 774: Profile = environmentalist
# Agent 775: Profile = normal
# Agent 776: Profile = environmentalist
# Agent 777: Profile = environmentalist
# Agent 778: Profile = normal
# Agent 779: Profile = normal
# Agent 780: Profile = normal
# Agent 781: Profile = normal
# Agent 782: Profile = normal
# Agent 783: Profile = normal
# Agent 784: Profile = environmentalist
# Agent 785: Profile = normal
# Agent 786: Profile = environmentalist
# Agent 787: Profile = environmentalist
# Agent 788: Profile = environmentalist
# Agent 789: Profile = normal
# Agent 790: Profile = normal
# Agent 791: Profile = normal
# Agent 792: Profile = normal
# Agent 793: Profile = normal
# Agent 794: Profile = environmentalist
# Agent 795: Profile = environmentalist
# Agent 796: Profile = environmentalist
# Agent 797: Profile = environmentalist
# Agent 798: Profile = normal
# Agent 799: Profile = normal
# Agent 800: Profile = normal
# Agent 801: Profile = normal
# Agent 802: Profile = normal
# Agent 803: Profile = environmentalist
# Agent 804: Profile = normal
# Agent 805: Profile = normal
# Agent 806: Profile = normal
# Agent 807: Profile = normal
# Agent 808: Profile = environmentalist
# Agent 809: Profile = normal
# Agent 810: Profile = normal
# Agent 811: Profile = normal
# Agent 812: Profile = normal
# Agent 813: Profile = environmentalist
# Agent 814: Profile = normal
# Agent 815: Profile = normal
# Agent 816: Profile = normal
# Agent 817: Profile = environmentalist
# Agent 818: Profile = environmentalist
# Agent 819: Profile = normal
# Agent 820: Profile = normal
# Agent 821: Profile = normal
# Agent 822: Profile = environmentalist
# Agent 823: Profile = environmentalist
# Agent 824: Profile = normal
# Agent 825: Profile = normal
# Agent 826: Profile = normal
# Agent 827: Profile = normal
# Agent 828: Profile = normal
# Agent 829: Profile = normal
# Agent 830: Profile = environmentalist
# Agent 831: Profile = normal
# Agent 832: Profile = environmentalist
# Agent 833: Profile = normal
# Agent 834: Profile = environmentalist
# Agent 835: Profile = environmentalist
# Agent 836: Profile = normal
# Agent 837: Profile = environmentalist
# Agent 838: Profile = environmentalist
# Agent 839: Profile = normal
# Agent 840: Profile = normal
# Agent 841: Profile = environmentalist
# Agent 842: Profile = normal
# Agent 843: Profile = environmentalist
# Agent 844: Profile = normal
# Agent 845: Profile = environmentalist
# Agent 846: Profile = normal
# Agent 847: Profile = normal
# Agent 848: Profile = normal
# Agent 849: Profile = normal
# Agent 850: Profile = normal
# Agent 851: Profile = normal
# Agent 852: Profile = normal
# Agent 853: Profile = normal
# Agent 854: Profile = normal
# Agent 855: Profile = normal
# Agent 856: Profile = normal
# Agent 857: Profile = normal
# Agent 858: Profile = environmentalist
# Agent 859: Profile = normal
# Agent 860: Profile = normal
# Agent 861: Profile = normal
# Agent 862: Profile = normal
# Agent 863: Profile = environmentalist
# Agent 864: Profile = normal
# Agent 865: Profile = normal
# Agent 866: Profile = normal
# Agent 867: Profile = environmentalist
# Agent 868: Profile = normal
# Agent 869: Profile = normal
# Agent 870: Profile = normal
# Agent 871: Profile = normal
# Agent 872: Profile = environmentalist
# Agent 873: Profile = normal
# Agent 874: Profile = normal
# Agent 875: Profile = normal
# Agent 876: Profile = normal
# Agent 877: Profile = normal
# Agent 878: Profile = normal
# Agent 879: Profile = normal
# Agent 880: Profile = environmentalist
# Agent 881: Profile = environmentalist
# Agent 882: Profile = environmentalist
# Agent 883: Profile = normal
# Agent 884: Profile = normal
# Agent 885: Profile = normal
# Agent 886: Profile = normal
# Agent 887: Profile = environmentalist
# Agent 888: Profile = normal
# Agent 889: Profile = normal
# Agent 890: Profile = environmentalist
# Agent 891: Profile = normal
# Agent 892: Profile = environmentalist
# Agent 893: Profile = normal
# Agent 894: Profile = normal
# Agent 895: Profile = environmentalist
# Agent 896: Profile = normal
# Agent 897: Profile = normal
# Agent 898: Profile = environmentalist
# Agent 899: Profile = environmentalist
# Agent 900: Profile = normal
# Agent 901: Profile = environmentalist
# Agent 902: Profile = normal
# Agent 903: Profile = normal
# Agent 904: Profile = normal
# Agent 905: Profile = normal
# Agent 906: Profile = normal
# Agent 907: Profile = normal
# Agent 908: Profile = normal
# Agent 909: Profile = environmentalist
# Agent 910: Profile = environmentalist
# Agent 911: Profile = normal
# Agent 912: Profile = environmentalist
# Agent 913: Profile = normal
# Agent 914: Profile = environmentalist
# Agent 915: Profile = environmentalist
# Agent 916: Profile = environmentalist
# Agent 917: Profile = normal
# Agent 918: Profile = normal
# Agent 919: Profile = normal
# Agent 920: Profile = environmentalist
# Agent 921: Profile = normal
# Agent 922: Profile = environmentalist
# Agent 923: Profile = environmentalist
# Agent 924: Profile = normal
# Agent 925: Profile = normal
# Agent 926: Profile = environmentalist
# Agent 927: Profile = normal
# Agent 928: Profile = normal
# Agent 929: Profile = normal
# Agent 930: Profile = normal
# Agent 931: Profile = normal
# Agent 932: Profile = normal
# Agent 933: Profile = normal
# Agent 934: Profile = environmentalist
# Agent 935: Profile = normal
# Agent 936: Profile = normal
# Agent 937: Profile = normal
# Agent 938: Profile = normal
# Agent 939: Profile = normal
# Agent 940: Profile = normal
# Agent 941: Profile = normal
# Agent 942: Profile = normal
# Agent 943: Profile = environmentalist
# Agent 944: Profile = normal
# Agent 945: Profile = environmentalist
# Agent 946: Profile = normal
# Agent 947: Profile = environmentalist
# Agent 948: Profile = normal
# Agent 949: Profile = normal
# Agent 950: Profile = normal
# Agent 951: Profile = normal
# Agent 952: Profile = environmentalist
# Agent 953: Profile = normal
# Agent 954: Profile = normal
# Agent 955: Profile = normal
# Agent 956: Profile = normal
# Agent 957: Profile = normal
# Agent 958: Profile = normal
# Agent 959: Profile = normal
# Agent 960: Profile = environmentalist
# Agent 961: Profile = environmentalist
# Agent 962: Profile = normal
# Agent 963: Profile = normal
# Agent 964: Profile = normal
# Agent 965: Profile = environmentalist
# Agent 966: Profile = environmentalist
# Agent 967: Profile = environmentalist
# Agent 968: Profile = normal
# Agent 969: Profile = normal
# Agent 970: Profile = normal
# Agent 971: Profile = environmentalist
# Agent 972: Profile = normal
# Agent 973: Profile = normal
# Agent 974: Profile = normal
# Agent 975: Profile = environmentalist
# Agent 976: Profile = environmentalist
# Agent 977: Profile = normal
# Agent 978: Profile = environmentalist
# Agent 979: Profile = normal
# Agent 980: Profile = normal
# Agent 981: Profile = normal
# Agent 982: Profile = normal
# Agent 983: Profile = normal
# Agent 984: Profile = normal
# Agent 985: Profile = environmentalist
# Agent 986: Profile = environmentalist
# Agent 987: Profile = normal
# Agent 988: Profile = normal
# Agent 989: Profile = normal
# Agent 990: Profile = normal
# Agent 991: Profile = environmentalist
# Agent 992: Profile = normal
# Agent 993: Profile = normal
# Agent 994: Profile = environmentalist
# Agent 995: Profile = environmentalist
# Agent 996: Profile = normal
# Agent 997: Profile = normal
# Agent 998: Profile = normal
# Agent 999: Profile = normal
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)

# %% [markdown]
# # 4. Discussion

# %% [markdown]
# ## 4.1 c_d, normal, betas遍历

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import matplotlib.dates as mdates  # 用于处理日期刻度

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载最大值和最小值文件
max_file_path = 'baseline_daily_usage_df_max.csv'  # 替换为你的最大值文件路径
min_file_path = 'baseline_daily_usage_df_min.csv'  # 替换为你的最小值文件路径

# 读取最大值和最小值数据
max_values = pd.read_csv(max_file_path, index_col=0)
min_values = pd.read_csv(min_file_path, index_col=0)

# 参数遍历设置
c_d_ratios = [(0.4, 0.6), (0.5, 0.5), (0.6, 0.4), (0.7, 0.3)]
normal_env_ratios = [(9, 1), (8, 2),(7, 3), (6, 4), (5, 5)]
betas = [1, 2, 5, 10, 25, 50]

# 遍历所有组合
for normal_env_ratio in normal_env_ratios:
    for beta in betas:
        plt.figure(figsize=(12, 8))  # 为当前 normal_env_ratio 和 beta 创建一张图
        max_values.index = pd.to_datetime(max_values.index)  # 将索引转换为日期时间格式 
        # 绘制阴影区域（最大值和最小值之间的区域）
        plt.fill_between(
            max_values.index, min_values['WaterUsage'], max_values['WaterUsage'], 
            color='gray', alpha=0.3, label='Min-Max Range'
        )

        # 用于存储当前模拟的结果
        current_results = []

        for c_d_ratio in c_d_ratios:
            # 运行模型
            model = StudentModel(
                num_agents=1240,
                start_date="2023-05-19",
                holiday_effects=holiday_effects,
                beta=beta,
                normal_env_ratio=normal_env_ratio,
                num_neighbors=10,
                c_d_ratio=c_d_ratio,
                interaction_interval=30  # 固定为 30
            )

            # 运行365天的模拟
            for _ in range(365):
                model.step()  # 调用模型的step方法，检查是否需要进行交互
                model.datacollector.collect(model)  # 收集数据

            # 获取代理变量数据并进行汇总
            water_data = model.datacollector.get_agent_vars_dataframe()

            # 按照步骤 (Step) 汇总每个代理的 daily_usage
            daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
            # 将 step 转换为实际日期
            daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]
            daily_usage.index = pd.to_datetime(daily_usage.index).tz_localize(None)

            # 设置索引名称为 'ds'
            daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'

            # 绘制当前组合的模拟结果
            plt.plot(
                daily_usage.index,
                daily_usage,
                lw=2,
                label=f"c_d_ratio={c_d_ratio}"
            )

            # 计算 'environmentalist' 和 'normal' 代理人的数量
            env_total = sum(1 for agent in model.schedule.agents if agent.profile == 'environmentalist')
            normal_total = sum(1 for agent in model.schedule.agents if agent.profile == 'normal')

            # 计算总代理人数量
            total_agents = len(model.schedule.agents)

            # 计算每类代理人的比例
            env_normal_ratio = env_total / total_agents, normal_total / total_agents

            # 保存每一天的用水量数据到 current_results
            for date, usage in daily_usage.items():
                current_results.append({
                    "c_d_ratio": c_d_ratio,
                    "beta": beta,
                    "normal_env_ratio": normal_env_ratio,
                    "date": date,
                    "water_usage": usage,
                    "env_ratio": env_normal_ratio[0],
                    "normal_ratio": env_normal_ratio[1]
                })

        # 设置标题，增加 normal_env_ratio 信息
        plt.title(
            f"Daily Water Usage (β={beta}, r={normal_env_ratio})",
            fontsize=16
        )
        plt.xlabel("Days", fontsize=14)
        plt.ylabel("Total Water Usage (kWh)", fontsize=14)
        plt.grid(True)

        # 优化横坐标日期显示
        ax = plt.gca()  # 获取当前轴
        ax.xaxis.set_major_locator(mdates.MonthLocator())  # 每月显示一个标签
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # 设置日期格式
        plt.xticks(rotation=45)  # 旋转标签避免重叠

        plt.tight_layout()  # 自动调整布局
        plt.legend()
        plt.savefig(f"simulation_c_d_{c_d_ratio}_r_{normal_env_ratio}_beta_{beta}.png")
        plt.close()

        # 将当前结果保存为 Excel 文件
        result_df = pd.DataFrame(current_results)
        output_file = f"30%_education_simulation_results_r_{normal_env_ratio}_beta_{beta}.xlsx"
        result_df.to_excel(output_file, index=False)

        print(f"Simulation results saved to {output_file}")

print("All simulations complete.")
# Out:
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_1.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_2.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_5.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_10.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_25.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(9, 1)_beta_50.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_1.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_2.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_5.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_10.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_25.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(8, 2)_beta_50.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_1.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_2.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_5.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_10.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_25.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(7, 3)_beta_50.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_1.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_2.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_5.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_10.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_25.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(6, 4)_beta_50.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_1.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_2.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_5.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_10.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_25.xlsx
# Simulation results saved to 30%_education_simulation_results_r_(5, 5)_beta_50.xlsx
# All simulations complete.

# %% [markdown]
# 结论：
# （1）β=5 是一个比较温和的策略；
#
# （2）Normal：Environmentalist = 6:4 是一个比较平衡的策略；
#
# （3）c_d_ratio=0.5 和 参加清洁生产导论的学生=[]比例关系，需要讨论

# %%
model = StudentModel(
    num_agents=1240,
    start_date="2023-05-19",
    holiday_effects=holiday_effects,
    beta=beta,
    normal_env_ratio=normal_env_ratio,
    num_neighbors=10,
    c_d_ratio=c_d_ratio,
    interaction_interval=30  # 固定为 30
)

# 运行365天的模拟
for _ in range(365):
    model.step()  # 调用模型的step方法，检查是否需要进行交互
    model.datacollector.collect(model)  # 收集数据

# 获取代理变量数据并进行汇总
water_data = model.datacollector.get_agent_vars_dataframe()

# 按照步骤 (Step) 汇总每个代理的 daily_usage
daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
# Out:
# d:\app\Anaconda\envs\test\lib\site-packages\mesa\agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)

# %%
# 运行模型
# model = StudentModel(num_agents=1000, start_date="2023-05-15", holiday_effects=holiday_effects, beta=1.0)
agents_data = pd.DataFrame([
    {
        "faculty": agent.faculty,
        "grade": agent.grade,
        "green_education": agent.green_education,
        "profile": agent.profile
    }
    for agent in model.schedule.agents
])

# %% [markdown]
# ## 4.2 对于教育接受教育的讨论【StudentModel-AgentModel的更广参数比例】

# %%
import random
import numpy as np
from numpy.polynomial.polynomial import Polynomial
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from mesa import Agent, Model
from mesa.time import RandomActivation
from numpy.random import normal
from mesa.datacollection import DataCollector  # 导入数据收集器，用于记录模型和主体的数据。
import networkx as nx


# 学生主体类
class StudentAgent(Agent):
    def __init__(self, unique_id, model, summer_start, summer_end, winter_start, winter_end, holiday_effects, profile="normal", grade=None, faculty=None, green_education=False,c_d_ratio=(0.5, 0.5)):
        """
        初始化学生主体。
        Args:
            unique_id (int): 学生唯一编号。
            model (Model): 模型对象。
            summer_start (str): 暑假开始日期（YYYY-MM-DD）。
            summer_end (str): 暑假结束日期（YYYY-MM-DD）。
            winter_start (str): 寒假开始日期（YYYY-MM-DD）。
            winter_end (str): 寒假结束日期（YYYY-MM-DD）。
            holiday_effects (dict): 假期效应字典，键为日期字符串（YYYY-MM-DD），值为假期类型。
            profile (str): 学生行为类型。
            grade (str): 学生年级。
            faculty (str): 学生专业。
            green_education (bool): 是否参与绿色教育课程。
        """
        super().__init__(unique_id, model)
        # print(self.current_date)
        self.is_on_campus = True  # 是否在校状态

        # 设置寒暑假信息
        self.summer_start = datetime.strptime(summer_start, "%Y-%m-%d")
        self.summer_end = datetime.strptime(summer_end, "%Y-%m-%d")
        self.winter_start = datetime.strptime(winter_start, "%Y-%m-%d")
        self.winter_end = datetime.strptime(winter_end, "%Y-%m-%d")

        # 假期效应和参数
        self.holiday_effects = holiday_effects

        # 社会学信息
        self.profile = profile
        self.grade = grade
        self.faculty = faculty
        self.green_education = green_education
        self.c, self.d = c_d_ratio

        # 基础用水量
        self.base_consumption = self.calculate_base_consumption()

        # 每天淋浴和洗衣服的概率
        self.shower_probs = [0.60, 0.65, 0.65, 0.63, 0.64, 0.62, 0.70]
        self.laundry_probs = [0.40, 0.40, 0.40, 0.40, 0.45, 0.45, 0.45]

        # 内嵌的暑假和寒假多项式系数
        self._summer_coefficients = [1.29118706e+02, -5.03312290e+00, 3.04662047e-01,
                                     -1.17554861e-02, 1.97107970e-04, -1.08127357e-06]
        self._winter_coefficients = [9.64941223e+01, -3.89556082e+00, -2.82518473e-01,
                                     1.75204478e-02, -1.02462403e-04, -2.31572036e-06]
        self.summer_probability_poly = Polynomial(self._summer_coefficients)
        self.winter_probability_poly = Polynomial(self._winter_coefficients)


    def calculate_behavior_utilities(self, neighbors_behavior):
        """
        根据邻居行为计算行为效用。
        """
        V_env = neighbors_behavior["environmentalist"]
        V_normal = neighbors_behavior["normal"]

        # 根据是否接受绿色教育，获取行为效用的系数【这个系数设置的太小，会使得转变和不转变收到邻居的影响较小，同样a/b/c/d不要求加起来和为1之类的】
        if self.green_education:
            a, b, c, d = 0.7, 0.3, self.c, self.d
        else:
            a, b, c, d = 0.7, 0.3, 0.3, 0.7

        if self.profile == "environmentalist":
            U_env_to_env = a * V_env
            U_env_to_normal = b * V_normal
            return U_env_to_env, U_env_to_normal
        else:  # self.profile == "normal"
            U_normal_to_env = c * V_env
            U_normal_to_normal = d * V_normal
            return U_normal_to_env, U_normal_to_normal

    def calculate_base_consumption(self):
        """定义基础设备的每日用水量（单位：升）。"""
        # 根据 profile 设置基础用水量
        if self.profile == "environmentalist":
            base_usage = {"toilet": 6, "sink": 12}
        else:  # profile == "normal"
            base_usage = {"toilet": 11, "sink": 17}
        
        return sum(base_usage.values())

    def calculate_daily_water_usage(self):
        """计算每日用水量。"""
        if not self.is_on_campus:
            return 0  # 如果不在校，直接返回0

        day_of_week = self.model.current_date.weekday()  # 直接从模型获取当前日期
        daily_consumption = self.base_consumption

        # 根据 profile 设置额外用水量参数
        if self.profile == "environmentalist":
            shower_usage = 60
            laundry_usage = 100
        else:  # profile == "normal"
            shower_usage = 80
            laundry_usage = 110

        # 计算额外用水量
        if random.random() < self.shower_probs[day_of_week]:
            daily_consumption += shower_usage
        if random.random() < self.laundry_probs[day_of_week]:
            daily_consumption += laundry_usage

        # 加入正态分布随机扰动（均值为 daily_consumption，标准差为 5% 的 daily_consumption）
        daily_consumption_with_noise = max(0, normal(daily_consumption, daily_consumption * 0.05))
        return daily_consumption_with_noise

    def update_on_campus_status(self):
        current_date = self.model.current_date  # 使用模型的当前日期
        if self.summer_start <= current_date <= self.summer_end:
            day_count = (current_date - self.summer_start).days
            on_campus_probability = self.summer_probability_poly(day_count) / 100
        elif self.winter_start <= current_date <= self.winter_end:
            day_count = (current_date - self.winter_start).days
            on_campus_probability = self.winter_probability_poly(day_count) / 100
        else:
            if current_date in self.holiday_effects:
                daily_effect = sum(self.holiday_effects[current_date].values())
                on_campus_probability = 0.9 - daily_effect
            else:
                on_campus_probability = np.random.normal(0.9, 0.01)

        on_campus_probability = max(0, min(on_campus_probability, 1))
        self.is_on_campus = np.random.rand() < on_campus_probability


    def get_water(self):
        """执行每日更新并返回每日用水量。"""
        self.update_on_campus_status()
        # print(self.model.current_date, self.is_on_campus)
        daily_usage = self.calculate_daily_water_usage()
        return daily_usage

# %%
class StudentModel(Model):
    def __init__(self, num_agents, start_date, holiday_effects, beta=1.0, normal_env_ratio=(7, 3), num_neighbors=4, c_d_ratio=(0.5, 0.5), interaction_interval=30,course_attendance_ratio=None):
        # 显式调用父类的初始化方法
        super().__init__()
        self.num_agents = num_agents
        self.holiday_effects = holiday_effects
        self.schedule = RandomActivation(self)
        
        # 初始化模拟开始日期
        self.current_date = datetime.strptime(start_date, "%Y-%m-%d")

        # 社会学比例
        self.faculty_total_ratio = {"A": [100, 100, 100, 100], "B": [100, 100, 100, 100], "C": [25, 25, 25, 25], "D": [25, 25, 25, 25]}
        self.course_attendance_ratio = course_attendance_ratio if course_attendance_ratio else {
            "A": [13, 30, 24, 13],
            "B": [4, 7, 6, 3],
            "C": [4, 7, 6, 3],
            "D": [1, 2, 1, 1]
        }
        
        # 创建数据收集器
        self.datacollector = DataCollector(
            agent_reporters={
                "WaterUsage": lambda a: a.get_water()  # 调用 get_water 方法并记录其返回值
            }
        )
        self.interaction_groups = []  # 存储分组信息
        # 设置 beta 参数，默认为 1.0
        self.beta = beta
        self.num_neighbors = num_neighbors  # Number of neighbors for each agent
        self.c_d_ratio = c_d_ratio  # Store the c_d_ratio
        self.interaction_interval = interaction_interval
        self.normal_env_ratio = normal_env_ratio  # Store the ratio
        self.create_agents()

                
    def create_agents(self):
        """创建学生主体并加入调度器。"""
        # 打印调试信息，确保 c_d_ratio 被正确传递
        
        for i in range(self.num_agents):
            faculty, grade = self.assign_faculty_and_grade()
            green_education = self.assign_green_education(faculty, grade)
            profile = self.assign_profile()
            summer_start, summer_end = "2023-06-26", "2023-08-31"
            winter_start, winter_end = "2024-01-21", "2024-02-25"
            agent = StudentAgent(
                unique_id=i,
                model=self,
                summer_start=summer_start,
                summer_end=summer_end,
                winter_start=winter_start,
                winter_end=winter_end,
                holiday_effects=self.holiday_effects,
                profile=profile,
                grade=grade,
                faculty=faculty,
                green_education=green_education,
                c_d_ratio=self.c_d_ratio
            )
            self.schedule.add(agent)

    def assign_faculty_and_grade(self):
        """根据比例随机分配专业和年级。"""
        faculty = random.choices(population=list(self.faculty_total_ratio.keys()), weights=[sum(self.faculty_total_ratio[f]) for f in self.faculty_total_ratio])[0]
        grade = random.choices(population=["大一", "大二", "大三", "大四"], weights=self.faculty_total_ratio[faculty])[0]
        return faculty, grade

    def assign_green_education(self, faculty, grade):
        """根据课程比例决定是否参加绿色教育。"""
        grades = ["大一", "大二", "大三", "大四"]
        grade_index = grades.index(grade)
        course_ratio = self.course_attendance_ratio[faculty][grade_index]
        total_students_in_grade = self.faculty_total_ratio[faculty][grade_index]
        return random.random() < (course_ratio / total_students_in_grade)

    def assign_profile(self):
        """根据外部输入的比例分配 Normal 和 Environmentalist。"""
        normal_weight, env_weight = self.normal_env_ratio  # Use the external ratio
        return random.choices(population=["normal", "environmentalist"], weights=[normal_weight, env_weight])[0]
        
    def create_interaction_groups(self):
        """根据小世界网络生成代理的交互组"""
        # 创建小世界网络
        G = nx.watts_strogatz_graph(self.num_agents, self.num_neighbors, 0.2)  # 4个邻居，重连概率为0.2

        # 基于年级、学科、是否参加清洁生产导论课程建立连接
        for node in G.nodes():
            agent = self.agents[node]
            neighbors = list(G.neighbors(node))
            
            # 确保每个邻居的连接是双向的
            for neighbor in neighbors:
                # 确保在邻居的列表中也有反向链接
                if agent.grade == self.agents[neighbor].grade:
                    G[node][neighbor]['weight'] = 2
                elif agent.faculty == self.agents[neighbor].faculty:
                    G[node][neighbor]['weight'] = 1.5
                elif agent.green_education == self.agents[neighbor].green_education:
                    G[node][neighbor]['weight'] = 1.2
                else:
                    G[node][neighbor]['weight'] = 1

        # 确保每个代理的邻居是双向的
        self.interaction_groups = []
        for node in G.nodes():
            neighbors = list(G.neighbors(node))
            group = [(self.agents[node], [self.agents[neighbor] for neighbor in neighbors])]
            self.interaction_groups.append(group)
        
        # 输出调试信息，查看是否是双向连接
        # print(f"Created {len(self.interaction_groups)} interaction groups.")

        # 检查每个代理的邻居是否双向连接
        for node in G.nodes():
            # print(f"Checking neighbors for Node {node}")
            # print(list(G.neighbors(node)))
            neighbors = list(G.neighbors(node))
            for neighbor in neighbors:
                if node not in list(G.neighbors(neighbor)):
                    print(f"Warning: Node {node} and Node {neighbor} are not bidirectional.")
        
    def interact_agents(self):
        """
        处理每组内的交互逻辑。
        """
        # 用来保存所有代理的行为更新决策
        updates = []

        # 对每个组进行交互
        for group in self.interaction_groups:
            for agent, neighbors in group:
                # 统计邻居行为
                neighbors_behavior = {
                    "environmentalist": sum(1 for a in neighbors if a.profile == "environmentalist") / len(neighbors),
                    "normal": sum(1 for a in neighbors if a.profile == "normal") / len(neighbors),
                }

                # 计算行为效用并决定是否更新行为
                if agent.profile == "environmentalist":
                    U_env_to_env, U_env_to_normal = agent.calculate_behavior_utilities(neighbors_behavior)
                    # 在计算效用时乘以 beta
                    U_env_to_env *= self.beta
                    U_env_to_normal *= self.beta
                    P_env_to_env = np.exp(U_env_to_env) / (np.exp(U_env_to_env) + np.exp(U_env_to_normal))
                    updates.append((agent, "environmentalist" if random.random() < P_env_to_env else "normal"))
                else:  # agent.profile == "normal"
                    U_normal_to_env, U_normal_to_normal = agent.calculate_behavior_utilities(neighbors_behavior)
                    # 在计算效用时乘以 beta
                    U_normal_to_env *= self.beta
                    U_normal_to_normal *= self.beta
                    P_normal_to_env = np.exp(U_normal_to_env) / (np.exp(U_normal_to_env) + np.exp(U_normal_to_normal))
                    updates.append((agent, "environmentalist" if random.random() < P_normal_to_env else "normal"))

        # 一轮交互结束后，再统一更新所有代理的状态
        for agent, new_profile in updates:
            agent.profile = new_profile
            # print(f"Agent {agent.unique_id} updated to: {agent.profile}")


    def step(self):
        """运行模型单步。"""
        # 1. 更新日期
        # print(f"Running step for {self.current_date}")
        self.current_date += timedelta(days=1)

        # 2. 每30天进行一次学生交互
        if (self.current_date - datetime.strptime("2023-05-15", "%Y-%m-%d")).days % self.interaction_interval == 0:
            self.create_interaction_groups()  # 创建新的交互组
            # print(f"Running interaction for {self.current_date}")
            self.interact_agents()

        # 2. 更新每个代理的状态
        self.schedule.step()
        

        # 3. 收集每日数据（如每个学生的用水量）
        self.datacollector.collect(self)

    def get_collected_data(self):
        """获取已收集的数据，返回DataFrame格式以便后续分析或绘图。"""
        return self.datacollector.get_agent_vars_dataframe()

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import matplotlib.dates as mdates  # 用于处理日期刻度

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载最大值和最小值文件
max_file_path = 'baseline_daily_usage_df_max.csv'  # 替换为你的最大值文件路径
min_file_path = 'baseline_daily_usage_df_min.csv'  # 替换为你的最小值文件路径

# 读取最大值和最小值数据
max_values = pd.read_csv(max_file_path, index_col=0)
min_values = pd.read_csv(min_file_path, index_col=0)

# 参数遍历设置
c_d_ratios = [(0.4, 0.6), (0.5, 0.5), (0.6, 0.4), (0.7, 0.3)]
course_attendance_ratios = [
    {"A": [13, 30, 24, 13], "B": [4, 7, 6, 3], "C": [4, 7, 6, 3], "D": [1, 2, 1, 1]},  # 原始比例
    {"A": [26, 60, 48, 26], "B": [8, 14, 12, 6], "C": [8, 14, 12, 6], "D": [2, 4, 2, 2]},  # 加倍比例
    {"A": [39, 90, 72, 39], "B": [12, 21, 18, 9], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]},  # 三倍比例
    {"A": [52, 120, 96, 52], "B": [16, 28, 24, 12], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]},  # 四倍比例
    {"A": [65, 150, 120, 65], "B": [20, 35, 30, 15], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]}  # 五倍比例
]

# 遍历所有组合
for cour in course_attendance_ratios:
    plt.figure(figsize=(12, 8))  
    max_values.index = pd.to_datetime(max_values.index)  # 将索引转换为日期时间格式 
    # 绘制阴影区域（最大值和最小值之间的区域）
    plt.fill_between(
        max_values.index, min_values['WaterUsage'], max_values['WaterUsage'], 
        color='gray', alpha=0.3, label='Min-Max Range'
    )

    # 用于存储当前模拟的结果
    current_results = []
    for c_d_ratio in c_d_ratios:
        # 运行模型
        model = StudentModel(
            num_agents=1240,
            start_date="2023-05-19",
            holiday_effects=holiday_effects,
            beta=5,
            normal_env_ratio=(6,4),
            num_neighbors=10,
            c_d_ratio=c_d_ratio,
            interaction_interval=30,  # 固定为 30
            course_attendance_ratio=cour
        )

        # 运行365天的模拟
        for _ in range(365):
            model.step()  # 调用模型的step方法，检查是否需要进行交互
            model.datacollector.collect(model)  # 收集数据

        # 获取代理变量数据并进行汇总
        water_data = model.datacollector.get_agent_vars_dataframe()

        # 按照步骤 (Step) 汇总每个代理的 daily_usage
        daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
        # 将 step 转换为实际日期
        daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]
        daily_usage.index = pd.to_datetime(daily_usage.index).tz_localize(None)

        # 设置索引名称为 'ds'
        daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'

        # 绘制当前组合的模拟结果
        plt.plot(
            daily_usage.index,
            daily_usage,
            lw=2,
            label=f"c_d_ratio={c_d_ratio}",
        )

        # 计算 'environmentalist' 和 'normal' 代理人的数量
        env_total = sum(1 for agent in model.schedule.agents if agent.profile == 'environmentalist')
        normal_total = sum(1 for agent in model.schedule.agents if agent.profile == 'normal')

        # 计算总代理人数量
        total_agents = len(model.schedule.agents)

        # 计算每类代理人的比例
        env_normal_ratio = env_total / total_agents, normal_total / total_agents

        # 保存每一天的用水量数据到 current_results
        for date, usage in daily_usage.items():
            current_results.append({
                "c_d_ratio": c_d_ratio,  # 循环参数之一
                "course_attendance_ratio": cour,  # 循环参数之二
                "date": date,  # 日期
                "water_usage": usage,  # 用水量
                "env_ratio": env_normal_ratio[0],  # 环保型代理人的比例
                "normal_ratio": env_normal_ratio[1]  # 普通代理人的比例
            })

    # 修改标题，使用 c_d_ratio 和 course_attendance_ratio 的信息
    attendance_ratio_sum = sum(cour["A"])  # 获取当前 course_attendance_ratio 的总和
    plt.title(
        f"Daily Water Usage (c_d_ratio={c_d_ratio}, course_sum={attendance_ratio_sum})",
        fontsize=16
    )
    plt.xlabel("Days", fontsize=14)
    plt.ylabel("Total Water Usage (kWh)", fontsize=14)
    plt.grid(True)

    # 优化横坐标日期显示
    ax = plt.gca()  # 获取当前轴
    ax.xaxis.set_major_locator(mdates.MonthLocator())  # 每月显示一个标签
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # 设置日期格式
    plt.xticks(rotation=45)  # 旋转标签避免重叠

    plt.tight_layout()  # 自动调整布局
    plt.legend()
    output_image = f"simulation_cdr_{c_d_ratio}_cour_{attendance_ratio_sum}.png"
    plt.savefig(output_image)
    plt.close()

    # 将当前结果保存为 Excel 文件
    result_df = pd.DataFrame(current_results)
    output_file = f"simulation_results_cdr_{c_d_ratio}_cour_{attendance_ratio_sum}.xlsx"
    result_df.to_excel(output_file, index=False)

    print(f"Simulation results saved to {output_file}")

print("All simulations complete.")
# Out:
# Simulation results saved to simulation_results_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_results_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_results_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_results_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_results_cdr_(0.7, 0.3)_cour_400.xlsx
# All simulations complete.

# %% [markdown]
# ## 4.3 对于所有参数的初步讨论

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import matplotlib.dates as mdates  # 用于处理日期刻度

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载最大值和最小值文件
max_file_path = 'baseline_daily_usage_df_max.csv'  # 替换为你的最大值文件路径
min_file_path = 'baseline_daily_usage_df_min.csv'  # 替换为你的最小值文件路径

# 读取最大值和最小值数据
max_values = pd.read_csv(max_file_path, index_col=0)
min_values = pd.read_csv(min_file_path, index_col=0)

# 参数遍历设置
c_d_ratios = [(0.4, 0.6), (0.5, 0.5), (0.6, 0.4), (0.7, 0.3)]
course_attendance_ratios = [
    {"A": [13, 30, 24, 13], "B": [4, 7, 6, 3], "C": [4, 7, 6, 3], "D": [1, 2, 1, 1]},  # 原始比例
    {"A": [26, 60, 48, 26], "B": [8, 14, 12, 6], "C": [8, 14, 12, 6], "D": [2, 4, 2, 2]},  # 加倍比例
    {"A": [39, 90, 72, 39], "B": [12, 21, 18, 9], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]},  # 三倍比例
    {"A": [52, 120, 96, 52], "B": [16, 28, 24, 12], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]},  # 四倍比例
    {"A": [65, 150, 120, 65], "B": [20, 35, 30, 15], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]}  # 五倍比例
]
num_neighbors_list = [6, 10, 20, 35, 50]  # 新增的 num_neighbors 参数
normal_env_ratios = [ (5, 5),(6, 4),(7, 3),(8, 2),(9, 1)]  # 新增的 normal_env_ratio 参数

# 遍历所有组合
for normal_env_ratio in normal_env_ratios:
    for num_neighbors in num_neighbors_list:
        for cour in course_attendance_ratios:
            plt.figure(figsize=(12, 8))  
            max_values.index = pd.to_datetime(max_values.index)  # 将索引转换为日期时间格式 
            # 绘制阴影区域（最大值和最小值之间的区域）
            plt.fill_between(
                max_values.index, min_values['WaterUsage'], max_values['WaterUsage'], 
                color='gray', alpha=0.3, label='Min-Max Range'
            )

            # 用于存储当前模拟的结果
            current_results = []
            for c_d_ratio in c_d_ratios:
                # 运行模型
                model = StudentModel(
                    num_agents=1240,
                    start_date="2023-05-19",
                    holiday_effects=holiday_effects,
                    beta=5,
                    normal_env_ratio=normal_env_ratio,  # 动态传入 normal_env_ratio
                    num_neighbors=num_neighbors,  # 动态传入 num_neighbors
                    c_d_ratio=c_d_ratio,
                    interaction_interval=30,  # 固定为 30
                    course_attendance_ratio=cour
                )

                # 运行365天的模拟
                for _ in range(365):
                    model.step()  # 调用模型的step方法，检查是否需要进行交互
                    model.datacollector.collect(model)  # 收集数据

                # 获取代理变量数据并进行汇总
                water_data = model.datacollector.get_agent_vars_dataframe()

                # 按照步骤 (Step) 汇总每个代理的 daily_usage
                daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
                # 将 step 转换为实际日期
                daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]
                daily_usage.index = pd.to_datetime(daily_usage.index).tz_localize(None)

                # 设置索引名称为 'ds'
                daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'

                # 绘制当前组合的模拟结果
                plt.plot(
                    daily_usage.index,
                    daily_usage,
                    lw=2,
                    label=f"c_d_ratio={c_d_ratio}",
                )

                # 计算 'environmentalist' 和 'normal' 代理人的数量
                env_total = sum(1 for agent in model.schedule.agents if agent.profile == 'environmentalist')
                normal_total = sum(1 for agent in model.schedule.agents if agent.profile == 'normal')

                # 计算总代理人数量
                total_agents = len(model.schedule.agents)

                # 计算每类代理人的比例
                env_normal_ratio = env_total / total_agents, normal_total / total_agents

                # 保存每一天的用水量数据到 current_results
                for date, usage in daily_usage.items():
                    current_results.append({
                        "c_d_ratio": c_d_ratio,  # 循环参数之一
                        "course_attendance_ratio": cour,  # 循环参数之二
                        "num_neighbors": num_neighbors,  # 新增参数
                        "normal_env_ratio": normal_env_ratio,  # 新增参数
                        "date": date,  # 日期
                        "water_usage": usage,  # 用水量
                        "env_ratio": env_normal_ratio[0],  # 环保型代理人的比例
                        "normal_ratio": env_normal_ratio[1]  # 普通代理人的比例
                    })

            # 修改标题，使用动态参数信息
            attendance_ratio_sum = sum(cour["A"])  # 获取当前 course_attendance_ratio 的总和
            plt.title(
                f"Daily Water Usage (num_neighbors={num_neighbors}, normal_env_ratio={normal_env_ratio}, course_sum={attendance_ratio_sum})",
                fontsize=16
            )
            plt.xlabel("Days", fontsize=14)
            plt.ylabel("Total Water Usage (kWh)", fontsize=14)
            plt.grid(True)

            # 优化横坐标日期显示
            ax = plt.gca()  # 获取当前轴
            ax.xaxis.set_major_locator(mdates.MonthLocator())  # 每月显示一个标签
            ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # 设置日期格式
            plt.xticks(rotation=45)  # 旋转标签避免重叠

            plt.tight_layout()  # 自动调整布局
            plt.legend()
            output_image = f"simulation_neighbors_{num_neighbors}_normal_{normal_env_ratio[0]}_{normal_env_ratio[1]}_cdr_{c_d_ratio}_cour_{attendance_ratio_sum}.png"
            plt.savefig(output_image)
            plt.close()

            # 将当前结果保存为 Excel 文件
            result_df = pd.DataFrame(current_results)
            output_file = f"simulation_neighbors_{num_neighbors}_normal_{normal_env_ratio[0]}_{normal_env_ratio[1]}_cdr_{c_d_ratio}_cour_{attendance_ratio_sum}.xlsx"
            result_df.to_excel(output_file, index=False)

            print(f"Simulation results saved to {output_file}")

print("All simulations complete.")
# Out:
# Simulation results saved to simulation_neighbors_6_normal_5_5_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_6_normal_5_5_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_6_normal_5_5_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_6_normal_5_5_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_6_normal_5_5_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_10_normal_5_5_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_10_normal_5_5_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_10_normal_5_5_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_10_normal_5_5_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_10_normal_5_5_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_20_normal_5_5_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_20_normal_5_5_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_20_normal_5_5_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_20_normal_5_5_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_20_normal_5_5_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_35_normal_5_5_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_35_normal_5_5_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_35_normal_5_5_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_35_normal_5_5_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_35_normal_5_5_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_50_normal_5_5_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_50_normal_5_5_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_50_normal_5_5_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_50_normal_5_5_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_50_normal_5_5_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_6_normal_6_4_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_6_normal_6_4_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_6_normal_6_4_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_6_normal_6_4_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_6_normal_6_4_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_10_normal_6_4_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_10_normal_6_4_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_10_normal_6_4_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_10_normal_6_4_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_10_normal_6_4_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_20_normal_6_4_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_20_normal_6_4_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_20_normal_6_4_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_20_normal_6_4_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_20_normal_6_4_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_35_normal_6_4_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_35_normal_6_4_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_35_normal_6_4_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_35_normal_6_4_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_35_normal_6_4_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_50_normal_6_4_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_50_normal_6_4_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_50_normal_6_4_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_50_normal_6_4_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_50_normal_6_4_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_6_normal_7_3_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_6_normal_7_3_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_6_normal_7_3_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_6_normal_7_3_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_6_normal_7_3_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_10_normal_7_3_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_10_normal_7_3_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_10_normal_7_3_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_10_normal_7_3_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_10_normal_7_3_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_20_normal_7_3_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_20_normal_7_3_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_20_normal_7_3_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_20_normal_7_3_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_20_normal_7_3_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_35_normal_7_3_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_35_normal_7_3_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_35_normal_7_3_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_35_normal_7_3_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_35_normal_7_3_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_50_normal_7_3_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_50_normal_7_3_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_50_normal_7_3_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_50_normal_7_3_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_50_normal_7_3_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_6_normal_8_2_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_6_normal_8_2_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_6_normal_8_2_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_6_normal_8_2_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_6_normal_8_2_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_10_normal_8_2_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_10_normal_8_2_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_10_normal_8_2_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_10_normal_8_2_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_10_normal_8_2_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_20_normal_8_2_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_20_normal_8_2_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_20_normal_8_2_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_20_normal_8_2_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_20_normal_8_2_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_35_normal_8_2_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_35_normal_8_2_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_35_normal_8_2_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_35_normal_8_2_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_35_normal_8_2_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_50_normal_8_2_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_50_normal_8_2_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_50_normal_8_2_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_50_normal_8_2_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_50_normal_8_2_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_6_normal_9_1_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_6_normal_9_1_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_6_normal_9_1_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_6_normal_9_1_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_6_normal_9_1_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_10_normal_9_1_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_10_normal_9_1_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_10_normal_9_1_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_10_normal_9_1_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_10_normal_9_1_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_20_normal_9_1_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_20_normal_9_1_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_20_normal_9_1_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_20_normal_9_1_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_20_normal_9_1_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_35_normal_9_1_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_35_normal_9_1_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_35_normal_9_1_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_35_normal_9_1_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_35_normal_9_1_cdr_(0.7, 0.3)_cour_400.xlsx
# Simulation results saved to simulation_neighbors_50_normal_9_1_cdr_(0.7, 0.3)_cour_80.xlsx
# Simulation results saved to simulation_neighbors_50_normal_9_1_cdr_(0.7, 0.3)_cour_160.xlsx
# Simulation results saved to simulation_neighbors_50_normal_9_1_cdr_(0.7, 0.3)_cour_240.xlsx
# Simulation results saved to simulation_neighbors_50_normal_9_1_cdr_(0.7, 0.3)_cour_320.xlsx
# Simulation results saved to simulation_neighbors_50_normal_9_1_cdr_(0.7, 0.3)_cour_400.xlsx
# All simulations complete.

# %%
# 运行模型
# model = StudentModel(num_agents=1000, start_date="2023-05-15", holiday_effects=holiday_effects, beta=1.0)
agents_data = pd.DataFrame([
    {
        "faculty": agent.faculty,
        "grade": agent.grade,
        "green_education": agent.green_education,
        "profile": agent.profile
    }
    for agent in model.schedule.agents
])

# %% [markdown]
# ## 4.4 对于每组交互个数&交互次数的讨论

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import matplotlib.dates as mdates  # 用于处理日期刻度

# 固定随机种子以保证结果可重复
random.seed(42)
np.random.seed(42)

# 加载假期效应数据
file_path = 'All_holiday_effects.xlsx'
holiday_effects_sheet = pd.ExcelFile(file_path).parse('Sheet1')
holiday_effects_sheet['ds'] = pd.to_datetime(holiday_effects_sheet['ds'])
holiday_effects = holiday_effects_sheet.set_index('ds').to_dict(orient='index')

# 加载最大值和最小值文件
max_file_path = 'baseline_daily_usage_df_max.csv'  # 替换为你的最大值文件路径
min_file_path = 'baseline_daily_usage_df_min.csv'  # 替换为你的最小值文件路径

# 读取最大值和最小值数据
max_values = pd.read_csv(max_file_path, index_col=0)
min_values = pd.read_csv(min_file_path, index_col=0)

# 参数遍历设置
interaction_intervals = [30, 60, 90, 120, 180]  # 新增的 interaction_interval 参数
num_neighbors_list = [6, 10, 20, 35, 50]  # 新增的 num_neighbors 参数

# 遍历所有组合
for neighbor in num_neighbors_list:
    plt.figure(figsize=(12, 8))  
    max_values.index = pd.to_datetime(max_values.index)  # 将索引转换为日期时间格式 
    # 绘制阴影区域（最大值和最小值之间的区域）
    plt.fill_between(
        max_values.index, min_values['WaterUsage'], max_values['WaterUsage'], 
        color='gray', alpha=0.3, label='Min-Max Range'
    )

    # 用于存储当前模拟的结果
    current_results = []
    for Interval in interaction_intervals:
        # 运行模型
        model = StudentModel(
            num_agents=1240,
            start_date="2023-05-19",
            holiday_effects=holiday_effects,
            beta=5,
            normal_env_ratio=(7,3),
            num_neighbors= neighbor,  # 动态传入 num_neighbors
            c_d_ratio=(0.6, 0.4),
            interaction_interval=Interval,  # 固定为 30
            course_attendance_ratio= {"A": [39, 90, 72, 39], "B": [12, 21, 18, 9], "C": [12, 21, 18, 9], "D": [3, 6, 3, 3]}
        )

        # 运行365天的模拟
        for _ in range(365):
            model.step()  # 调用模型的step方法，检查是否需要进行交互
            model.datacollector.collect(model)  # 收集数据

        # 获取代理变量数据并进行汇总
        water_data = model.datacollector.get_agent_vars_dataframe()

        # 按照步骤 (Step) 汇总每个代理的 daily_usage
        daily_usage = water_data.groupby("Step")["WaterUsage"].sum()/1000  # 获取该天的总用水量
        # 将 step 转换为实际日期
        daily_usage.index = [model.current_date - timedelta(days=(365 - step)) for step in daily_usage.index]
        daily_usage.index = pd.to_datetime(daily_usage.index).tz_localize(None)

        # 设置索引名称为 'ds'
        daily_usage.index.name = 'ds'  # 设置索引名称为 'ds'

        # 绘制当前组合的模拟结果
        plt.plot(
            daily_usage.index,
            daily_usage,
            lw=2,
            label=f"interaction_interval={Interval}",
        )

        # 计算 'environmentalist' 和 'normal' 代理人的数量
        env_total = sum(1 for agent in model.schedule.agents if agent.profile == 'environmentalist')
        normal_total = sum(1 for agent in model.schedule.agents if agent.profile == 'normal')

        # 计算总代理人数量
        total_agents = len(model.schedule.agents)

        # 计算每类代理人的比例
        env_normal_ratio = env_total / total_agents, normal_total / total_agents

        # 保存每一天的用水量数据到 current_results
        for date, usage in daily_usage.items():
            current_results.append({
                "interaction_interval": Interval,  # 新增参数
                "num_neighbors": neighbor,  # 新增参数
                "date": date,  # 日期
                "water_usage": usage,  # 用水量
                "env_ratio": env_normal_ratio[0],  # 环保型代理人的比例
                "normal_ratio": env_normal_ratio[1]  # 普通代理人的比例
            })

    # 修改标题，使用 num_neighbors 和 interaction_interval 的信息
    plt.title(
        f"Daily Water Usage (num_neighbors={neighbor})",
        fontsize=16
    )
    plt.xlabel("Days", fontsize=14)
    plt.ylabel("Total Water Usage (kWh)", fontsize=14)
    plt.grid(True)


    # 优化横坐标日期显示
    ax = plt.gca()  # 获取当前轴
    ax.xaxis.set_major_locator(mdates.MonthLocator())  # 每月显示一个标签
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # 设置日期格式
    plt.xticks(rotation=45)  # 旋转标签避免重叠

    plt.tight_layout()  # 自动调整布局
    plt.legend()
    output_image = f"simulation_neighbors_{neighbor}.png"
    plt.savefig(output_image)
    plt.close()


    # 将当前结果保存为 Excel 文件
    result_df = pd.DataFrame(current_results)
    output_file = f"simulation_results_neighbors_{neighbor}.xlsx"
    result_df.to_excel(output_file, index=False)

    print(f"Simulation results saved to {output_file}")

print("All simulations complete.")
# Out:
# Simulation results saved to simulation_results_neighbors_6.xlsx
# Simulation results saved to simulation_results_neighbors_10.xlsx
# Simulation results saved to simulation_results_neighbors_20.xlsx
# Simulation results saved to simulation_results_neighbors_35.xlsx
# Simulation results saved to simulation_results_neighbors_50.xlsx
# All simulations complete.

# %% [markdown]
# ## 4.5 对于在扩散中引入时间变量的讨论（季节变化的熵分析加入扩散模型）

# %% [markdown]
# # 5.结果

# %% [markdown]
# ## 5.1 不同分年级分专业的人效果

# %%
# 打印模型中Normal学生平均用水量
normal_students = [agent for agent in model.schedule.agents if agent.profile == "normal"]
normal_daily_usage = [agent.calculate_daily_water_usage() for agent in normal_students]
print("Normal学生平均用水量：", np.mean(normal_daily_usage))

# 打印模型中Environmentalist学生平均用水量
environmentalist_students = [agent for agent in model.schedule.agents if agent.profile == "environmentalist"]
environmentalist_daily_usage = [agent.calculate_daily_water_usage() for agent in environmentalist_students]
print("Environmentalist学生平均用水量：", np.mean(environmentalist_daily_usage))
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 # 打印模型中Normal学生平均用水量
#
# ----> 2 normal_students = [agent for agent in model.schedule.agents if agent.profile == "normal"]
#
#       3 normal_daily_usage = [agent.calculate_daily_water_usage() for agent in normal_students]
#
#       4 print("Normal学生平均用水量：", np.mean(normal_daily_usage))
#
#
#
# NameError: name 'model' is not defined

# %%
# 统计学生社会学信息并绘图
def plot_student_statistics(model):
    """
    根据生成的 agents 统计学生的社会学信息（专业、绿色教育、行为类型）并绘制图表。
    Args:
        model: StudentModel 对象
    """

    # 获取所有学生主体的属性
    agents_data = pd.DataFrame([
        {
            "faculty": agent.faculty,
            "grade": agent.grade,
            "green_education": agent.green_education,
            "profile": agent.profile
        }
        for agent in model.schedule.agents
    ])

    # 设置年级的排序顺序
    agents_data["grade"] = pd.Categorical(
    agents_data["grade"],
    categories=["大一", "大二", "大三", "大四"],
    ordered=True
)

    # 绘制学生专业和年级分布
    faculty_grade_distribution = agents_data.groupby(["grade", "faculty"]).size().unstack(fill_value=0)
    faculty_grade_distribution.plot(kind='bar', stacked=True, figsize=(10, 6))
    plt.title("学生专业分布", fontsize=14)
    plt.xlabel("年级", fontsize=12)
    plt.ylabel("学生人数", fontsize=12)
    plt.legend(title="专业", fontsize=12)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()


    # 提取已参与绿色教育的学生并按专业划分
    green_education_faculty_distribution = agents_data[agents_data["green_education"] == True] \
        .groupby(["grade", "faculty"]).size().unstack(fill_value=0)
    # 创建绘图
    fig, ax = plt.subplots(figsize=(12, 8))
    # 绘制已参与部分，按专业分堆叠
    green_education_faculty_distribution.plot(kind="bar", stacked=True, ax=ax, colormap="tab10", alpha=0.8 )
    # 设置图表标题和标签
    plt.title("学生绿色教育参与情况（已参与按专业划分）", fontsize=14)
    plt.xlabel("年级", fontsize=12)
    plt.ylabel("学生人数", fontsize=12)
    plt.legend(title="绿色教育与专业", fontsize=12)
    plt.grid(axis="y")
    plt.tight_layout()
    plt.show()

    # 绘制学生行为类型分布
    profile_distribution = agents_data["profile"].value_counts()
    profile_distribution.plot(kind='bar', figsize=(8, 6), color='skyblue')
    plt.title("学生行为类型分布", fontsize=14)
    plt.xlabel("行为类型", fontsize=12)
    plt.ylabel("学生人数", fontsize=12)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
plot_student_statistics(model)
